# %% [markdown]
# # 1. Install, Imports, Settings

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
plt.rcParams["figure.figsize"] = [10, 6]
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # 2. Load data

# %%
df = pd.read_csv("data/alertas_NNAJ_keywords.csv", sep="|")
print("Total Number of documents:", len(df))
print("Number of documents with no accesible text (pass protected):", len(df[df['Text'].isnull()]))
print("Number of documents with accesible text:",  len(df[df['Text'].notnull()]))
print("Number of documents mentioning NNAJ:",  len(df[df['NNAJ'] != "[]"]))
# Out:
# Total Number of documents: 1753
# Number of documents with no accesible text (pass protected): 5
# Number of documents with accesible text: 1748
# Number of documents mentioning NNAJ: 1140

# %%
df.drop(['NNAJ_clean_text', 'NNAJ_keywords', 'NNAJ_keywords2','NNAJ_keywords3'], axis = 1).head()
# Out:
#                                             Filename  \
# 0  AT N° 003-18 NAR-Cumbitara, Maguí Payán, Polic...
# 1                        AT N° 004-18 NAR-Tumaco.pdf
# 2                     AT N° 005-18 COR-Tierralta.pdf
# 3                      AT N° 006-18 ARA-Saravena.pdf
# 4  AT N° 007-18 MET-Puerto Lleras, Puerto Rico y ...
#
#                                                 Text          Subtype  \
# 0  Defensoria del Pueblo COLOMB IA Bogotá D.C., 5...  Alerta Temprana
# 1  Defensoría del Pueblo CO LO Mll.t. Carrera 9 #...  Alerta Temprana
# 2  Carrera 9 # 16 -21 Bogotá D.C. PBX: (57) (1) 3...  Alerta Temprana
# 3  Defensoría del Pueblo Carrera 9 # 16-21 Bogotá...  Alerta Temprana
# 4  San Vicente Bajo l' Margen Izquierda del río G...  Alerta Temprana
#
#           Type  Year                                               Path  \
# 0  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 003-18 NAR-...
# 1  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 004-18 NAR-...
# 2  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 005-18 COR-...
# 3  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 006-18 ARA-...
# 4  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 007-18 MET-...
#
#   Departamento                                               NNAJ
# 0       Nariño  ['Por lo anterior; desde el Sistema de Alertas...
# 1       Nariño  ['Los territorios dejados por las FARC - EP, f...
# 2      Córdoba  ['En ese sentido, la población civil se encuen...
# 3       Arauca  ['También se advierte· el riesgo de secuestros...
# 4         Meta  ['Integrantes del Nuev o Partido FAR( **niños*...

# %% [markdown]
# # 3. Number of NNAJ Documents by Departamento

# %%
df = df[df['NNAJ'] != "[]"]

# %%
dft = df.groupby(["Departamento", "Type", "Subtype"]).agg({"Filename":"count"})
dft = dft.reset_index()
dft = pd.pivot_table(dft, values='Filename', index=['Departamento'],
                    columns=['Subtype'], aggfunc=np.sum)
dft = dft.fillna(0)
dft["Total"] = dft.sum(axis=1)
dft
# Out:
# Subtype                   Alerta Temprana  Informe de Riesgo  \
# Departamento
# Amazonas                              1.0                2.0
# Antioquia                            28.0               22.0
# Arauca                                8.0               17.0
# Atlántico                             2.0                4.0
# Bogotá                                5.0                6.0
# Bolívar                              10.0               24.0
# Boyacá                                3.0                5.0
# Caldas                                3.0                6.0
# Caquetá                               3.0               11.0
# Casanare                              4.0                3.0
# Cauca                                20.0               21.0
# Cesar                                 5.0                6.0
# Chocó                                25.0               38.0
# Countrywide                           5.0                2.0
# Cundinamarca                          9.0               10.0
# Córdoba                               9.0               24.0
# Guainía                               1.0                1.0
# Guaviare                              3.0                5.0
# Huila                                 4.0                8.0
# La Guajira                            1.0               10.0
# Magdalena                             4.0               10.0
# Meta                                 12.0               16.0
# Nariño                               14.0               28.0
# Norte de Santander                   14.0               18.0
# Putumayo                              8.0               13.0
# Quindío                               3.0               52.0
# Risaralda                             4.0               14.0
# San Andrés y Providencia              1.0                0.0
# Santander                             0.0                0.0
# Sucre                                 3.0                9.0
# Tolima                                4.0               13.0
# Valle del Cauca                      24.0               38.0
# Vaupés                                2.0                4.0
# Vichada                               1.0                5.0
#
# Subtype                   Informe de Seguimiento  Notas  Total
# Departamento
# Amazonas                                     0.0    0.0    3.0
# Antioquia                                    4.0   14.0   68.0
# Arauca                                       2.0   26.0   53.0
# Atlántico                                    1.0    6.0   13.0
# Bogotá                                       2.0    7.0   20.0
# Bolívar                                     11.0   14.0   59.0
# Boyacá                                       1.0    1.0   10.0
# Caldas                                       3.0    4.0   16.0
# Caquetá                                      1.0   11.0   26.0
# Casanare                                     0.0    0.0    7.0
# Cauca                                        6.0   28.0   75.0
# Cesar                                        3.0    4.0   18.0
# Chocó                                       10.0   21.0   94.0
# Countrywide                                  1.0    0.0    8.0
# Cundinamarca                                 2.0   20.0   41.0
# Córdoba                                      6.0   16.0   55.0
# Guainía                                      0.0    0.0    2.0
# Guaviare                                     2.0    7.0   17.0
# Huila                                        2.0    2.0   16.0
# La Guajira                                   1.0    7.0   19.0
# Magdalena                                    2.0    3.0   19.0
# Meta                                         5.0   21.0   54.0
# Nariño                                      12.0   27.0   81.0
# Norte de Santander                           8.0   14.0   54.0
# Putumayo                                     4.0    7.0   32.0
# Quindío                                     12.0   12.0   79.0
# Risaralda                                    2.0    2.0   22.0
# San Andrés y Providencia                     0.0    0.0    1.0
# Santander                                    0.0    1.0    1.0
# Sucre                                        1.0    5.0   18.0
# Tolima                                       2.0    9.0   28.0
# Valle del Cauca                              9.0   42.0  113.0
# Vaupés                                       1.0    2.0    9.0
# Vichada                                      0.0    3.0    9.0

# %%
plt.figure()
plt.rcParams.update({'font.size': 14})

dft.drop("Total", axis=1).plot(kind="barh", figsize=(20, 20), stacked=True, width=0.8, alpha=0.8, rot=0)
plt.title("Number of Documents by Departments")
plt.xlabel("")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# # 4 Total of documents by Department - Descending Order

# %%
dft['Total'].sort_values(ascending = False).to_frame()
# Out:
#                           Total
# Departamento
# Valle del Cauca           113.0
# Chocó                      94.0
# Nariño                     81.0
# Quindío                    79.0
# Cauca                      75.0
# Antioquia                  68.0
# Bolívar                    59.0
# Córdoba                    55.0
# Norte de Santander         54.0
# Meta                       54.0
# Arauca                     53.0
# Cundinamarca               41.0
# Putumayo                   32.0
# Tolima                     28.0
# Caquetá                    26.0
# Risaralda                  22.0
# Bogotá                     20.0
# La Guajira                 19.0
# Magdalena                  19.0
# Sucre                      18.0
# Cesar                      18.0
# Guaviare                   17.0
# Huila                      16.0
# Caldas                     16.0
# Atlántico                  13.0
# Boyacá                     10.0
# Vaupés                      9.0
# Vichada                     9.0
# Countrywide                 8.0
# Casanare                    7.0
# Amazonas                    3.0
# Guainía                     2.0
# Santander                   1.0
# San Andrés y Providencia    1.0

# %% [markdown]
# # 6. Statistical Distribution - Departments

# %%
dft['Total'].describe().to_frame()
# Out:
#             Total
# count   34.000000
# mean    33.529412
# std     29.827012
# min      1.000000
# 25%     10.750000
# 50%     19.500000
# 75%     54.000000
# max    113.000000

# %% [markdown]
# # 7. Documents distributed by Department - Timeline

# %% [markdown]
# ### Las lineas verticales dividen los periodos de estudio que establecimos en la metodologia del paper.

# %%
dftd = df.groupby(["Departamento", "Year"]).agg({"Filename":"count"})
dftd = dftd.reset_index()
dftd = pd.pivot_table(dftd, values='Filename', index=['Departamento'],
                    columns=['Year'], aggfunc=np.sum)
dftd = dftd.fillna(0)
dftd["Total"] = dftd.sum(axis=1)

# %%
import matplotlib.pyplot as plt

sns.set(font_scale=1.2)
palette = sns.cubehelix_palette(n_colors= 7, rot=0, dark=0.15, light=1, as_cmap=True)

plt.figure(figsize=(25, 18))
ax = sns.heatmap(dftd.drop("Total", axis=1), annot=True, linewidth=0, cmap=palette)

for text in ax.texts:
    if text.get_text() == '0':
        text.set_text('')
        
ax.vlines([5, 11, 16],  ymin = 0, ymax = 45,
           colors = 'purple',
          linestyle='solid'
           )
cbar = ax.collections[0].colorbar

plt.show()

# %% [markdown]
# # 7. Export HTML

# %%
# !jupyter nbconvert --to html 12_Distribution_of_NNAJ_Docs_Departamentos.ipynb
# Out:
# [NbConvertApp] Converting notebook 12_Distribution_of_NNAJ_Docs_Departamentos.ipynb to html
# [NbConvertApp] Writing 1138226 bytes to 12_Distribution_of_NNAJ_Docs_Departamentos.html
