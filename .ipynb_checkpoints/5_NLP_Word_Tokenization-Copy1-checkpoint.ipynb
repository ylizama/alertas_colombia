# %% [markdown]
# # 1. Installs, Imports and Settings

# %%
#!pip install spacy==3.1.1 #restart runtime after this
#!python -m spacy download es_core_news_sm

import csv
import pandas as pd
pd.options.display.max_rows
pd.set_option('display.max_colwidth', None)

import string
import operator
from itertools import islice
from collections import Counter

import spacy
nlp = spacy.load('es_core_news_sm')

from nltk import ngrams
import nltk as nltk
from nltk.corpus import stopwords

# %% [markdown]
# #  2. Reading files

# %%
df = pd.read_csv('data/alertas.csv', sep="|")
df = df[df["Text"] != " "]
print("Size of Data:", len(df))
print()
print("Columns : ", list(df.columns))
# Out:
# Size of Data: 666
#
# Columns :  ['Filename', 'Text', 'Type', 'Year']

# %% [markdown]
# # 3. Functions

# %%
stop_words = stopwords.words('spanish') + ["at", "ala", "026", "1", "27", "06", "18", "www", "01", "8000914814", "¡"]

punct_signs = list(string.punctuation)
punct_signs += ['…','¿','•','”','“','–','&','∑','[',']', '▪', "I ’m", "️❤", "⠀ ⠀ ⠀", "⠀ ⠀"]


def clean_text(text):   
    clean_text = []
    for p in punct_signs:
        text = text.replace(p, ' ') 
    
    clean_text = text.lower().split()
    clean_text = [w for w in clean_text if w not in stop_words]
    
    nlp.max_length = len(' '.join(clean_text)) + 100
    doc = nlp(' '.join(clean_text))
    txt = []
    for token in doc:  
        if token.lemma:
            txt.append(token.lemma_)
    return txt

#m is the number of top ngrams.
def getNGrams(text, n, m):
    h_dict = {}   
    ngramas = list(ngrams(text, n))
    for grams in ngramas:
        words = ' '.join(grams).strip()
        if words not in h_dict:
            h_dict[words] = 0
        h_dict[words] = h_dict[words] + 1
        
    sorted_dict = sorted(h_dict.items(), key=operator.itemgetter(1), reverse=True)
    top_values = list(islice(sorted_dict, m))
    return [(r[0], r[1], round(r[1]/len(ngramas)*100,2)) for r in top_values]

def printNgrams(data, m):
    Ngrams = []
    unigrams = getNGrams(data, 1, m)
    bigrams = getNGrams(data, 2 , m)
    trigrams = getNGrams(data, 3 , m)
    for i in range(0,m):
        Ngrams.append(unigrams[i] + bigrams[i] + trigrams[i])
    df = pd.DataFrame(Ngrams, columns=['Unigrams', 'Absolute Freq', 'Relative Freq', 
                                       'Bigrams', 'Absolute Freq', 'Relative Freq', 
                                       'Trigrams', 'Absolute Freq', 'Relative Freq',]) 
    return df

# %% [markdown]
# # 4. Top 20 Ngrams in the whole corpus

# %% [markdown]
# #### Stopwords, emojies, and punctuation has been removed from the corpus.
# #### Ngrams are formed by the lemma of the word. For example: "go" includes the frequencies of go, goes, went, gone, etc..

# %%
printNgrams(clean_text(' '.join(df['Text'])), 20)

# %% [markdown]
# ## 4.1 Top 20 Ngrams in Advertencias

# %%
dfg = df[df["Type"] == "advertencia"]
printNgrams(clean_text(' '.join(dfg['Text'])), 20)

# %% [markdown]
# ## 4.2 Top 20 Ngrams in Seguimiento

# %%
dfg = df[df["Type"] == "seguimiento"]
printNgrams(clean_text(' '.join(dfg['Text'])), 20)
# Out:
#        Unigrams  Absolute Freq  Relative Freq              Bigrams  \
# 0         líder            366           0.81     derechos humanos
# 1      nacional            359           0.80         líder social
# 2      derechos            352           0.78    persona defensora
# 3        riesgo            329           0.73   defensora derechos
# 4        social            302           0.67        humanos líder
# 5       humanos            295           0.66       defensorio gov
# 6        acción            272           0.61               gov co
# 7     municipio            237           0.53    plantilla vigente
# 8        pueblo            236           0.53         co plantilla
# 9          2018            223           0.50  informe seguimiento
# 10       medida            210           0.47         grupo armado
# 11      persona            196           0.44     defensoer pueblo
# 12       armado            193           0.43  seguimiento persona
# 13   protección            192           0.43       línea nacional
# 14   prevención            167           0.37    defensor derechos
# 15  seguimiento            160           0.36        armado ilegal
# 16   defensorio            158           0.35  remitir información
# 17      informe            157           0.35      alerta temprano
# 18         caso            157           0.35     riesgo advertido
# 19        grupo            157           0.35    campesino agrario
#
#     Absolute Freq  Relative Freq                       Trigrams  \
# 0             280           0.62     defensora derechos humanos
# 1             217           0.48     persona defensora derechos
# 2             130           0.29         derechos humanos líder
# 3             126           0.28           humanos líder social
# 4              99           0.22              defensorio gov co
# 5              94           0.21           co plantilla vigente
# 6              93           0.21               gov co plantilla
# 7              92           0.20  seguimiento persona defensora
# 8              88           0.20    informe seguimiento persona
# 9              85           0.19      defensor derechos humanos
# 10             83           0.18            grupo armado ilegal
# 11             76           0.17         plantilla vigente 2017
# 12             76           0.17                2008 ntc gp1000
# 13             74           0.16                ntc gp1000 2009
# 14             57           0.13      línea nacional defensorio
# 15             54           0.12        nacional defensorio gov
# 16             50           0.11           líder social persona
# 17             46           0.10       social persona defensora
# 18             46           0.10         campesino agrario pnis
# 19             46           0.10                     bogotá d c
#
#     Absolute Freq  Relative Freq
# 0             124           0.28
# 1             108           0.24
# 2              98           0.22
# 3              92           0.20
# 4              90           0.20
# 5              88           0.20
# 6              84           0.19
# 7              76           0.17
# 8              75           0.17
# 9              53           0.12
# 10             42           0.09
# 11             30           0.07
# 12             30           0.07
# 13             30           0.07
# 14             30           0.07
# 15             30           0.07
# 16             28           0.06
# 17             24           0.05
# 18             23           0.05
# 19             21           0.05

# %% [markdown]
# ## 5. Exporting to html

# %%
# !jupyter nbconvert --to html 5_NLP_Word_Tokenization.ipynb
