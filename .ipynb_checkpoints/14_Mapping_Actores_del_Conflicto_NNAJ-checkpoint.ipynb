# %% [markdown]
# # 1. Install, Imports, Settings

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import spacy
from spacy.lang.es.examples import sentences 
#!python -m spacy download es_core_news_md
nlp = spacy.load("es_core_news_md")
from collections import Counter
import string, math, json

# %%
plt.rcParams["figure.figsize"] = [10, 6]
# %config InlineBackend.figure_format = 'retina'

punct = string.punctuation +'”“'

# %% [markdown]
# # 2. Loading data

# %%
grupos = {
    "Grupo Armado Organizado" : ["GAO"],
    "Grupo Armado Ilegal" : ["GAI"],
    "Grupo Armado Organizado Residual" : ["GAOR", "GAO-R", "grupo armado organizado - residual" ], 
    "Ejército de Liberación Nacional" : ["ELN"],
    "Autodefensas Gaitanistas de Colombia" : ["AGC"],
    "Fuerzas Armadas Revolucionarias - Ejército del Pueblo" : ["FARC", 
                                         "Fuerzas Armadas Revolucionarias de Colombia",
                                         "Fuerzas Armadas Revolucionarias Ejército del Pueblo",
                                         "FARCEP", "FARC-EP", "FARC EP"
                                        ],
    "Grupo delincuencial organizado" : ["GDO", ],
    "Jalisco Nueva Generación": [],
    "Bandas Criminales" : ["BACRIM", "Bandas Emergentes"],
    "Autodefensas Unidas de Colombia" : ["AUC", ],
    "Grupos posdesmovilización": [],
    "Ejército de Liberación Popular": ["EPL"],
    "Clan del Golfo" : ["AGC"],
}

children = ["NNAJ", "niños", "niñas", "adolescentes", "jóvenes", "NNA"]

narco_grupos  = ["Cartel del Amazonas",  
        "Cartel de Los Nevados",
        "Cartel de Bogotá",
        "Cartel de Buga",
        "Cartel de Medellín",
        "Oficina de Envigado",
        "Cartel de Cali",
        "Cartel del Caquetá",
        "Cartel del Norte del Valle",
        "Los Rastrojos",
        "Cartel de la Costa Atlántica",
        "Cartel de La Guajira",
        "Cartel del Cauca",
        "Los Caparrapos",
        "Los Paisas",
        "Águilas Negras",
        "Los Puntilleros",
        "Ejército Revolucionario Popular Antisubversivo de Colombia",
        "Los Pelusos",
        "GDO Los Pachenca",
        "Clan Gnecco Cerchar",
        "Clan Bustamante", 
        "Activo Primer Frente",
        "Segunda Marquetalia", 
        "Los Zetas", 
        "Cartel de Sinaloa", 
        "Oficina de Envigado", 
        "La Terraza",
        "Robledo",
        "Pachelly",
        "La Sierra", 
        "Caicedo", 
        "Los Triana",
        "Clan del Oriente", 
        "La Unión",
        "Clan del Norte",
        "Los Costeños", 
        "Los Pachencha", 
        "La Cordillera",
        "La Gran Alianza",
        "Banda Local",
        "Norte del Valle",
        "Los Chuckys",
        "Los Chacales",
        "La Constru",
        "Los Caqueteños"]

POI = {
    "Evaristo Porras": "Papa Doc",
    "Luis Agustín Caicedo Velandia" : "Don Lucho", 
    "Víctor Manuel Mejía Múnera": "Pablo Arauca",
    "Miguel Ángel Mejía Múnera": "El Mellizo",
    "Ramón Quintero":"",
    "Pablo Escobar" : "El patrón",
    "Gonzalo Rodríguez Gacha": "",
    "Diego Fernando Murillo": "",
    "Gilberto Rodríguez Orejuela": "El Ajedrecista",
    "Miguel Rodríguez Orejuela": "",
    "Leonidas Vargas": "El Rey de Caquetá",
    "Luis Enrique Calle Serna": "",
    "Wilber Varela": "",
    "Alberto Orlandez Gamboa": "", 
    "Hermágoras González": "",
    "Nicolás Rodríguez Bautista" : " Gabino ", 
    "Iván Márquez": "",
    "Gentil Duarte": "",
    "Jorge Gnecco Cerchar": "", 
    "Jesús María Aguirre" :"Chucho Mercancía",
    "Megateo": "",  
    "Vicente Castaño": "", 
    "Emiliano Alcides Osorio": " Caín ",
    "Edgar Bustamante" : "El Yuca",
    "Manuel Marulanda Vélez" :" Tirofijo ",     
    "Jorge Briceño Suarez Mono": " Jojoy ",
    "Dairo Antonio Úsuga David": "",
    "Salvatore Mancuso": "",
    "Rodrigo Tovar": "",
    "Carlos Castaño Gil": "",
    "Justo Pastor Perafán": "Don Pepe"
}

loc = pd.read_csv("resources/Departamentos_y_municipios_de_Colombia.csv")
loc.head()
# Out:
#                             REGION  CÓDIGO DANE DEL DEPARTAMENTO DEPARTAMENTO  \
# 0  Región Eje Cafetero - Antioquia                             5    Antioquia
# 1  Región Eje Cafetero - Antioquia                             5    Antioquia
# 2  Región Eje Cafetero - Antioquia                             5    Antioquia
# 3  Región Eje Cafetero - Antioquia                             5    Antioquia
# 4  Región Eje Cafetero - Antioquia                             5    Antioquia
#
#    CÓDIGO DANE DEL MUNICIPIO   MUNICIPIO
# 0                      5.001    Medellín
# 1                      5.002   Abejorral
# 2                      5.004    Abriaquí
# 3                      5.021  Alejandría
# 4                      5.030       Amagá

# %%
dfnnaj = pd.read_csv("data/alertas_actors_NNAJ.csv", sep="|")
df = pd.read_csv("data/alertas_actors.csv", sep="|")
dfnnaj = dfnnaj.drop(['Unnamed: 0'], axis=1)
print("Total Number of documents:", len(df))
print("Total Number of documents NNAJ:", len(dfnnaj))
# Out:
# Total Number of documents: 1752
# Total Number of documents NNAJ: 1140

# %%
df.head()
# Out:
#                                             Filename          Subtype  \
# 0  AT N° 003-18 NAR-Cumbitara, Maguí Payán, Polic...  Alerta Temprana
# 1                        AT N° 004-18 NAR-Tumaco.pdf  Alerta Temprana
# 2                     AT N° 005-18 COR-Tierralta.pdf  Alerta Temprana
# 3                      AT N° 006-18 ARA-Saravena.pdf  Alerta Temprana
# 4  AT N° 007-18 MET-Puerto Lleras, Puerto Rico y ...  Alerta Temprana
#
#           Type  Year                                               Path  \
# 0  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 003-18 NAR-...
# 1  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 004-18 NAR-...
# 2  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 005-18 COR-...
# 3  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 006-18 ARA-...
# 4  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 007-18 MET-...
#
#   Departamento                                             Actors
# 0       Nariño  ['Grupo Armado Ilegal', 'Grupo Armado Ilegal',...
# 1       Nariño  ['Grupo Armado Ilegal', 'Grupo Armado Ilegal',...
# 2      Córdoba  ['Grupo Armado Ilegal', 'Grupo Armado Ilegal',...
# 3       Arauca  ['Grupo Armado Ilegal', 'Grupo Armado Ilegal',...
# 4         Meta  ['Grupo Armado Organizado', 'Grupo Armado Orga...

# %%
dfnnaj.tail(5)
# Out:
#                                                Filename  \
# 1135  IS N° 004-2022 a AT 048-20 PUT-Puerto Leguíza...
# 1136  IS N° 005-2022 a AT N° 041-19 CHO-Alto Baudó y...
# 1137                IS N° 006-2022 a AT N° 004-2021.pdf
# 1138  IS N° 011-2022 a AT N° 031-2020 MET-San Martín...
# 1139  IS N° 012-2022 a AT N° 042 de 2020 BOY-El Cocu...
#
#                      Subtype         Type  Year  \
# 1135  Informe de Seguimiento  Seguimiento  2022
# 1136  Informe de Seguimiento  Seguimiento  2022
# 1137  Informe de Seguimiento  Seguimiento  2022
# 1138  Informe de Seguimiento  Seguimiento  2022
# 1139  Informe de Seguimiento  Seguimiento  2022
#
#                                                    Path        Departamento  \
# 1135  data\Informes de Seguimiento\2022\IS N° 004-20...            Putumayo
# 1136  data\Informes de Seguimiento\2022\IS N° 005-20...               Chocó
# 1137  data\Informes de Seguimiento\2022\IS N° 006-20...  Norte de Santander
# 1138  data\Informes de Seguimiento\2022\IS N° 011-20...                Meta
# 1139  data\Informes de Seguimiento\2022\IS N° 012-20...              Boyacá
#
#                                             Actors_NNAJ
# 1135  ['Instituto Colombiano de Bienestar Familiar',...
# 1136  ['Frente de Guerra Occidental', 'Ejército de L...
# 1137  ['La Constru', 'La Constru', 'Servicio Naciona...
# 1138  ['Autodefensas Gaitanistas de Colombia', 'Band...
# 1139  ['Grupo Armado Ilegal', 'La Sierra', 'La Sierr...

# %% [markdown]
# # 3. Cleaning Duty

# %%
arts = ['la', 'los', 'el', 'las', 'una', 'un']
def replace_accents(w):
    return w.replace('á','a').replace('é','e').replace('í','i').replace('ó','o').replace('ú','u')

arts = ['la', 'los', 'el', 'las', 'una', 'un']
def replace_articles(w):
    w = [x for x in w.split() if x not in arts]
    return ' '.join(w)

def clean_segment(s):
    return replace_articles(replace_accents(s.lower()))
    
def clean_actors(entities):
    entities = entities.strip("']['").split("', '")
   
    if len(entities) == 0:
        return []
    
    #grupos
    for key, value in grupos.items():
        for v in value:
            entities = [key if clean_segment(e) == clean_segment(v) else e for e in entities]
           
    #narco grupos
    for v in narco_grupos:
        entities = [v if clean_segment(e) == clean_segment(v) else e for e in entities]
    return entities

df["Actors"] = df["Actors"].apply(clean_actors)
dfnnaj["Actors_NNAJ"] = dfnnaj["Actors_NNAJ"].apply(clean_actors)

# %%
len(df), len(dfnnaj)
# Out:
# (1752, 1140)

# %%
df.to_csv("data/alertas_actors.csv", sep="|")
df = df.set_index('Filename')
#remove duplicates
df = df[~df.index.duplicated(keep='first')]
df = df
df.head()
# Out:
#                                                             Subtype  \
# Filename
# AT N° 003-18 NAR-Cumbitara, Maguí Payán, Polica...  Alerta Temprana
# AT N° 004-18 NAR-Tumaco.pdf                         Alerta Temprana
# AT N° 005-18 COR-Tierralta.pdf                      Alerta Temprana
# AT N° 006-18 ARA-Saravena.pdf                       Alerta Temprana
# AT N° 007-18 MET-Puerto Lleras, Puerto Rico y V...  Alerta Temprana
#
#                                                            Type  Year  \
# Filename
# AT N° 003-18 NAR-Cumbitara, Maguí Payán, Polica...  Advertencia  2018
# AT N° 004-18 NAR-Tumaco.pdf                         Advertencia  2018
# AT N° 005-18 COR-Tierralta.pdf                      Advertencia  2018
# AT N° 006-18 ARA-Saravena.pdf                       Advertencia  2018
# AT N° 007-18 MET-Puerto Lleras, Puerto Rico y V...  Advertencia  2018
#
#                                                                                                  Path  \
# Filename
# AT N° 003-18 NAR-Cumbitara, Maguí Payán, Polica...  data\Advertencia_PDF\AT 2018\AT N° 003-18 NAR-...
# AT N° 004-18 NAR-Tumaco.pdf                         data\Advertencia_PDF\AT 2018\AT N° 004-18 NAR-...
# AT N° 005-18 COR-Tierralta.pdf                      data\Advertencia_PDF\AT 2018\AT N° 005-18 COR-...
# AT N° 006-18 ARA-Saravena.pdf                       data\Advertencia_PDF\AT 2018\AT N° 006-18 ARA-...
# AT N° 007-18 MET-Puerto Lleras, Puerto Rico y V...  data\Advertencia_PDF\AT 2018\AT N° 007-18 MET-...
#
#                                                    Departamento  \
# Filename
# AT N° 003-18 NAR-Cumbitara, Maguí Payán, Polica...       Nariño
# AT N° 004-18 NAR-Tumaco.pdf                              Nariño
# AT N° 005-18 COR-Tierralta.pdf                          Córdoba
# AT N° 006-18 ARA-Saravena.pdf                            Arauca
# AT N° 007-18 MET-Puerto Lleras, Puerto Rico y V...         Meta
#
#                                                                                                Actors
# Filename
# AT N° 003-18 NAR-Cumbitara, Maguí Payán, Polica...  [Grupo Armado Ilegal, Grupo Armado Ilegal, Aut...
# AT N° 004-18 NAR-Tumaco.pdf                         [Grupo Armado Ilegal, Grupo Armado Ilegal, Gru...
# AT N° 005-18 COR-Tierralta.pdf                      [Grupo Armado Ilegal, Grupo Armado Ilegal, Ejé...
# AT N° 006-18 ARA-Saravena.pdf                       [Grupo Armado Ilegal, Grupo Armado Ilegal, Ejé...
# AT N° 007-18 MET-Puerto Lleras, Puerto Rico y V...  [Grupo Armado Organizado, Grupo Armado Organiz...

# %%
dfnnaj.to_csv("data/alertas_actors_NNAJ.csv", sep="|")
dfnnaj = dfnnaj.set_index('Filename')
dfnnaj.tail()
# Out:
#                                                                    Subtype  \
# Filename
# IS N° 004-2022 a AT 048-20 PUT-Puerto Leguízam...  Informe de Seguimiento
# IS N° 005-2022 a AT N° 041-19 CHO-Alto Baudó y ...  Informe de Seguimiento
# IS N° 006-2022 a AT N° 004-2021.pdf                 Informe de Seguimiento
# IS N° 011-2022 a AT N° 031-2020 MET-San Martín.pdf  Informe de Seguimiento
# IS N° 012-2022 a AT N° 042 de 2020 BOY-El Cocuy...  Informe de Seguimiento
#
#                                                            Type  Year  \
# Filename
# IS N° 004-2022 a AT 048-20 PUT-Puerto Leguízam...  Seguimiento  2022
# IS N° 005-2022 a AT N° 041-19 CHO-Alto Baudó y ...  Seguimiento  2022
# IS N° 006-2022 a AT N° 004-2021.pdf                 Seguimiento  2022
# IS N° 011-2022 a AT N° 031-2020 MET-San Martín.pdf  Seguimiento  2022
# IS N° 012-2022 a AT N° 042 de 2020 BOY-El Cocuy...  Seguimiento  2022
#
#                                                                                                  Path  \
# Filename
# IS N° 004-2022 a AT 048-20 PUT-Puerto Leguízam...  data\Informes de Seguimiento\2022\IS N° 004-20...
# IS N° 005-2022 a AT N° 041-19 CHO-Alto Baudó y ...  data\Informes de Seguimiento\2022\IS N° 005-20...
# IS N° 006-2022 a AT N° 004-2021.pdf                 data\Informes de Seguimiento\2022\IS N° 006-20...
# IS N° 011-2022 a AT N° 031-2020 MET-San Martín.pdf  data\Informes de Seguimiento\2022\IS N° 011-20...
# IS N° 012-2022 a AT N° 042 de 2020 BOY-El Cocuy...  data\Informes de Seguimiento\2022\IS N° 012-20...
#
#                                                           Departamento  \
# Filename
# IS N° 004-2022 a AT 048-20 PUT-Puerto Leguízam...            Putumayo
# IS N° 005-2022 a AT N° 041-19 CHO-Alto Baudó y ...               Chocó
# IS N° 006-2022 a AT N° 004-2021.pdf                 Norte de Santander
# IS N° 011-2022 a AT N° 031-2020 MET-San Martín.pdf                Meta
# IS N° 012-2022 a AT N° 042 de 2020 BOY-El Cocuy...              Boyacá
#
#                                                                                           Actors_NNAJ
# Filename
# IS N° 004-2022 a AT 048-20 PUT-Puerto Leguízam...  [Instituto Colombiano de Bienestar Familiar, U...
# IS N° 005-2022 a AT N° 041-19 CHO-Alto Baudó y ...  [Frente de Guerra Occidental, Ejército de Libe...
# IS N° 006-2022 a AT N° 004-2021.pdf                 [La Constru, La Constru, Servicio Nacional de ...
# IS N° 011-2022 a AT N° 031-2020 MET-San Martín.pdf  [Autodefensas Gaitanistas de Colombia, Bandas ...
# IS N° 012-2022 a AT N° 042 de 2020 BOY-El Cocuy...  [Grupo Armado Ilegal, La Sierra, La Sierra, La...

# %%
df = df.to_frame()
df.head()
# Out:
#                                                                                                Actors
# Filename
# AT N° 003-18 NAR-Cumbitara, Maguí Payán, Polica...  [Grupo Armado Ilegal, Grupo Armado Ilegal, Aut...
# AT N° 004-18 NAR-Tumaco.pdf                         [Grupo Armado Ilegal, Grupo Armado Ilegal, Gru...
# AT N° 005-18 COR-Tierralta.pdf                      [Grupo Armado Ilegal, Grupo Armado Ilegal, Ejé...
# AT N° 006-18 ARA-Saravena.pdf                       [Grupo Armado Ilegal, Grupo Armado Ilegal, Ejé...
# AT N° 007-18 MET-Puerto Lleras, Puerto Rico y V...  [Grupo Armado Organizado, Grupo Armado Organiz...

# %%
#merging DFs
dftotal = pd.concat([dfnnaj, df.reindex(dfnnaj.index)], axis=1)
len(dftotal)
# Out:
# 1140

# %%
dftotal[dftotal['Actors_NNAJ'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Subtype, Type, Year, Path, Departamento, Actors_NNAJ, Actors]
# Index: []

# %%
dftotal = dftotal.reset_index()
dftotal.head()
# Out:
#                                             Filename          Subtype  \
# 0  AT N° 003-18 NAR-Cumbitara, Maguí Payán, Polic...  Alerta Temprana
# 1                        AT N° 004-18 NAR-Tumaco.pdf  Alerta Temprana
# 2                     AT N° 005-18 COR-Tierralta.pdf  Alerta Temprana
# 3                      AT N° 006-18 ARA-Saravena.pdf  Alerta Temprana
# 4  AT N° 007-18 MET-Puerto Lleras, Puerto Rico y ...  Alerta Temprana
#
#           Type  Year                                               Path  \
# 0  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 003-18 NAR-...
# 1  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 004-18 NAR-...
# 2  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 005-18 COR-...
# 3  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 006-18 ARA-...
# 4  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 007-18 MET-...
#
#   Departamento                                        Actors_NNAJ  \
# 0       Nariño       [RECOMENDACIONES A, Comisión lntersectorial]
# 1       Nariño  [Grupo Armado Ilegal, Fuerzas Armadas Revoluci...
# 2      Córdoba  [Grupo Armado Ilegal, Instituto Colombiano de ...
# 3       Arauca       [Derecho Internacional Humanitario, Policía]
# 4         Meta  [Nuev, Partido FAR, Defensoria del Pueblo, Fue...
#
#                                               Actors
# 0  [Grupo Armado Ilegal, Grupo Armado Ilegal, Aut...
# 1  [Grupo Armado Ilegal, Grupo Armado Ilegal, Gru...
# 2  [Grupo Armado Ilegal, Grupo Armado Ilegal, Ejé...
# 3  [Grupo Armado Ilegal, Grupo Armado Ilegal, Ejé...
# 4  [Grupo Armado Organizado, Grupo Armado Organiz...

# %%
dftotal.to_csv("data/alertas_actors_NNAJ.csv", sep="|", index=False)

# %% [markdown]
# # 4. Functions

# %%
df = pd.read_csv("data/alertas_actors_NNAJ.csv", sep="|")
df.head()
# Out:
#                                             Filename          Subtype  \
# 0  AT N° 003-18 NAR-Cumbitara, Maguí Payán, Polic...  Alerta Temprana
# 1                        AT N° 004-18 NAR-Tumaco.pdf  Alerta Temprana
# 2                     AT N° 005-18 COR-Tierralta.pdf  Alerta Temprana
# 3                      AT N° 006-18 ARA-Saravena.pdf  Alerta Temprana
# 4  AT N° 007-18 MET-Puerto Lleras, Puerto Rico y ...  Alerta Temprana
#
#           Type  Year                                               Path  \
# 0  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 003-18 NAR-...
# 1  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 004-18 NAR-...
# 2  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 005-18 COR-...
# 3  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 006-18 ARA-...
# 4  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 007-18 MET-...
#
#   Departamento                                        Actors_NNAJ  \
# 0       Nariño   ['RECOMENDACIONES A', 'Comisión lntersectorial']
# 1       Nariño  ['Grupo Armado Ilegal', 'Fuerzas Armadas Revol...
# 2      Córdoba  ['Grupo Armado Ilegal', 'Instituto Colombiano ...
# 3       Arauca   ['Derecho Internacional Humanitario', 'Policía']
# 4         Meta  ['Nuev', 'Partido FAR', 'Defensoria del Pueblo...
#
#                                               Actors
# 0  ['Grupo Armado Ilegal', 'Grupo Armado Ilegal',...
# 1  ['Grupo Armado Ilegal', 'Grupo Armado Ilegal',...
# 2  ['Grupo Armado Ilegal', 'Grupo Armado Ilegal',...
# 3  ['Grupo Armado Ilegal', 'Grupo Armado Ilegal',...
# 4  ['Grupo Armado Organizado', 'Grupo Armado Orga...

# %%
space_articles = []
red_flags = ['Telefax', 'procesoSubproceso Prevención y Protección Código','SAT', 'Alerta Temprana', 
             'Derecho Internacional Humanitario', 'SAT Código DPR', 
             'procesoSubproceso Prevención y Protección Código PPP02F10 ALERTA', 'SEGUIMIENTO', 
             'PARA', 'Frente', 'Nota de Seguimiento', 'PP', 'AT', 'LIBERTAD',  'Alertas Tempranas', 
             'P01 F07 Formato Nota de Seguimiento Versión 03 Vigente', 
             'Prevención y Protección Código PP', 'Bloque C', 'Comisión', 'POBLACION','Constitución Política', 
             'procesoSubproceso Prevención y Protección Código PP', 'Ejército', 'Sin', 'INFORME', 'MUSE', 
             'BIENES INDISPENSABLES PARA', 'Gobernación', 'A NO SER', 'cia', 'Alerta', 'RECOMENDACIONES A', 
            'NNA', 'Adolescentes', 'ADOLESCENTES', 'SAT INFORME DE RIESGO No']

arts = ['la', 'los', 'el', 'las']

# %%
def remove_flags(entities):
     return [e for e in entities if e not in red_flags]

def remove_articles(entities):
    new = []
    for i in range(0, len(entities) - 1):
            new.append(entities[i])
            for a in arts:
                if entities[i].lower().startswith(a + " "):
                    new[len(new)-1] = entities[i][len(a):]

    return new
                     
def fix_terms(entities):
    new = []
    for i in range(0, len(entities)):
        new.append(entities[i])
        # fix ELN
        if entities[i].startswith("ELN "):
                   new[len(new) - 1] =  "Ejército de Liberación Nacional"
        #fix Las FARC           
        elif entities[i].startswith("FARC") or entities[i].startswith("lasFARC") or entities[i].startswith("LasFARC"):
                   new[len(new) - 1] = "Fuerzas Armadas Revolucionarias - Ejército del Pueblo" 
                
        elif entities[i].startswith("Fuerzas Armadas Revolucionarias"):
                   new[len(new) - 1] = "Fuerzas Armadas Revolucionarias - Ejército del Pueblo" 
                
        elif entities[i].lower().startswith("urabe"):
                   new[len(new) - 1] = "Urabeños"     
                
        elif entities[i].startswith("UNP"):
                   new[len(new) - 1] = "Unidad Nacional de Protección"    
        
        elif entities[i].startswith("Acción Social"):
                   new[len(new) - 1] = "Agencia Presidencial para la Acción Social"
                
        elif entities[i].startswith("Al Instituto Colombiano de Bienestar Familiar") or entities[i].startswith("ICBF"):
                   new[len(new) - 1] = "Instituto Colombiano de Bienestar Familiar"
                
        elif entities[i].lower().startswith("armada"):
                   new[len(new) - 1] = "Armada Nacional"
                
        elif entities[i].lower().startswith("defensor"):
                   new[len(new) - 1] = "Defensoría del Pueblo"
                
    return new

def clean_list_actors(df, column):
    actors = df[column].sum()
    if type(actors) == str:
        actors = actors.strip("']['").split("', '")
    
    #remove articles
    actors = remove_articles(actors)
                     
    #fix some terms
    actors = fix_terms(actors)                               
                
    #remove red flags
    actors = remove_flags(actors)
    
    #remove blank spaces
    actors = [a.strip() for a in actors]
    
    return actors
    
def most_mentioned_actors(actors):           
    data = { 
             'actors': list(Counter(actors).keys()), 
             'frequency': list(Counter(actors).values())
           }

    counterdf = pd.DataFrame(data)
    counterdf = counterdf.groupby('actors').agg({'frequency' : 'sum'}).sort_values('frequency', ascending = False)
    return counterdf

# %% [markdown]
# # 4. Most Mentioned Actors - Top 20 in Documents that mention NNAJ

# %% [markdown]
# #### Los articulos se omiten por cuestiones de estandarizacion de los datos, pero por ejemplo Rastrojos se refiere a Los Rastrojos que es el nombre original, as'i pasa con Los Paisas, La Cordillera, La Constru, etc.

# %%
dfa = most_mentioned_actors(clean_list_actors(df, 'Actors'))
dfa[:20]
# Out:
#                                                     frequency
# actors
# Fuerzas Armadas Revolucionarias - Ejército del ...      11692
# Ejército de Liberación Nacional                          6024
# Autodefensas Unidas de Colombia                          5175
# Fuerza Pública                                           4560
# Águilas Negras                                           3347
# Rastrojos                                                2587
# Policía Nacional                                         2484
# Autodefensas Gaitanistas de Colombia                     2083
# Grupo Armado Ilegal                                      1685
# Constru                                                  1411
# Urabeños                                                 1370
# Policía                                                  1198
# Unidad Nacional de Protección                            1194
# Instituto Colombiano de Bienestar Familiar               1119
# Cordillera                                                952
# Fiscalía General de la Nación                             894
# Unión                                                     887
# Agencia Presidencial para la Acción Social                821
# Paisas                                                    778
# Ejército de Liberación Popular                            745

# %% [markdown]
# # 4.1 Most Mentioned Actors - Top 20 in the Same Sentence that mention  NNAJ - More Context

# %%
dfb = most_mentioned_actors(clean_list_actors(df, 'Actors_NNAJ'))
dfb[:20]
# Out:
#                                                     frequency
# actors
# Instituto Colombiano de Bienestar Familiar                628
# Fuerzas Armadas Revolucionarias - Ejército del ...        555
# Ejército de Liberación Nacional                           299
# Autodefensas Unidas de Colombia                           256
# Fuerza Pública                                            169
# Águilas Negras                                            162
# Rastrojos                                                 135
# Urabeños                                                  109
# Policía Nacional                                           98
# Comisión Intersectorial para la Prevención del ...         98
# Autodefensas Gaitanistas de Colombia                       85
# Alcaldías                                                  78
# Constru                                                    76
# Corte Constitucional                                       63
# Acción Comunal                                             61
# Fiscalía General de la Nación                              59
# Grupo Armado Ilegal                                        50
# Policía                                                    50
# Servicio Nacional de Aprendizaje                           46
# Agencia Presidencial para la Acción Social                 44

# %% [markdown]
# # 5. Statistical Distribution of Actors

# %%
dfa[dfa.frequency > 100].describe()
# Out:
#           frequency
# count    108.000000
# mean     637.009259
# std     1452.174049
# min      102.000000
# 25%      129.500000
# 50%      173.500000
# 75%      459.500000
# max    11692.000000

# %% [markdown]
# # 6. Top 10 actors in each period

# %%
df1 = df[df.Year < 2006]
df2 = df[(df.Year > 2005) & (df.Year < 2012)]
df3 = df[(df.Year > 2011) & (df.Year < 2017)]
df4 = df[df.Year > 2016]

# %% [markdown]
# # 6.1 2001 - 2005 (Conflicto, 2005 Justicia y Paz)

# %%
df1 = most_mentioned_actors(clean_list_actors(df1, 'Actors'))[:10]
df1
# Out:
#                                                     frequency
# actors
# Fuerzas Armadas Revolucionarias - Ejército del ...        891
# Autodefensas Unidas de Colombia                           888
# Ejército de Liberación Nacional                           185
# Fuerza Pública                                            174
# Autodefensas                                              152
# Red de Solidaridad Social                                  96
# Armada Nacional                                            86
# Cordillera                                                 73
# Policía                                                    49
# OEA                                                        48

# %%
df1[df1.frequency > 100].describe()
# Out:
#         frequency
# count    5.000000
# mean   458.000000
# std    394.084382
# min    152.000000
# 25%    174.000000
# 50%    185.000000
# 75%    888.000000
# max    891.000000

# %% [markdown]
# # 6.2 2006- 2011 (Conflicto)

# %%
df2 = most_mentioned_actors(clean_list_actors(df2, 'Actors'))[:10]
df2
# Out:
#                                                     frequency
# actors
# Fuerzas Armadas Revolucionarias - Ejército del ...       3253
# Autodefensas Unidas de Colombia                          1849
# Águilas Negras                                           1691
# Fuerza Pública                                           1355
# Rastrojos                                                 992
# Ejército de Liberación Nacional                           903
# Agencia Presidencial para la Acción Social                773
# Grupo Armado Ilegal                                       435
# Policía Nacional                                          422
# Paisas                                                    396

# %%
df2[df2.frequency > 100].describe()
# Out:
#        frequency
# count     10.000
# mean    1206.900
# std      885.147
# min      396.000
# 25%      519.500
# 50%      947.500
# 75%     1607.000
# max     3253.000

# %% [markdown]
# # 6.3 2012 - 2016 (Negociaciones de Paz, Acuerdo de La Habana)

# %%
df3 = most_mentioned_actors(clean_list_actors(df3, 'Actors'))[:10]
df3
# Out:
#                                                     frequency
# actors
# Fuerzas Armadas Revolucionarias - Ejército del ...       3179
# Ejército de Liberación Nacional                          1246
# Fuerza Pública                                           1245
# Rastrojos                                                1224
# Autodefensas Unidas de Colombia                          1066
# Urabeños                                                 1055
# Águilas Negras                                           1049
# Autodefensas Gaitanistas de Colombia                      725
# Policía Nacional                                          666
# Grupo Armado Ilegal                                       557

# %%
df3[df3.frequency > 100].describe()
# Out:
#          frequency
# count    10.000000
# mean   1201.200000
# std     738.403353
# min     557.000000
# 25%     806.000000
# 50%    1060.500000
# 75%    1239.750000
# max    3179.000000

# %% [markdown]
# # 6.4 2017 - 2022 (Post- Acuerdo)

# %%
df4 = most_mentioned_actors(clean_list_actors(df4, 'Actors'))[:10]
df4
# Out:
#                                                     frequency
# actors
# Fuerzas Armadas Revolucionarias - Ejército del ...       4369
# Ejército de Liberación Nacional                          3690
# Fuerza Pública                                           1786
# Autodefensas Unidas de Colombia                          1372
# Policía Nacional                                         1367
# Autodefensas Gaitanistas de Colombia                     1164
# Constru                                                   969
# Unidad Nacional de Protección                             947
# Grupo Armado Ilegal                                       688
# Águilas Negras                                            607

# %%
df4[df4.frequency > 100].describe()
# Out:
#          frequency
# count    10.000000
# mean   1695.900000
# std    1287.410014
# min     607.000000
# 25%     952.500000
# 50%    1265.500000
# 75%    1682.500000
# max    4369.000000

# %% [markdown]
# # 6. Export HTML

# %%
# !jupyter nbconvert --to html 14_Mapping_Actores_del_Conflicto_NNAJ.ipynb
# Out:
# [NbConvertApp] Converting notebook 14_Mapping_Actores_del_Conflicto_NNAJ.ipynb to html
# [NbConvertApp] Writing 690663 bytes to 14_Mapping_Actores_del_Conflicto_NNAJ.html
