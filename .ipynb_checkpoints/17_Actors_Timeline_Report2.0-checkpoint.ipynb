# %% [markdown]
# # 1. Imports, Installs, Settings

# %%
import seaborn 
import pandas as pd
import csv
from collections import Counter
#import string, math, json

# %% [markdown]
# # 2. Load Data

# %%
df = pd.read_csv("data/clean_NNAJ_actors.csv", sep="|")
df.head()
# Out:
#                                    Clean_NNAJ_actors  \
# 0                                Grupo Armado Ilegal
# 1  Fuerzas Armadas Revolucionarias - Ejército Del...
# 2                            Grupos Armados Ilegales
# 3                            Delincuencia Organizada
# 4  Fuerzas Armadas Revolucionarias - Ejército Del...
#
#                       Filename  Year
# 0  AT N° 004-18 NAR-Tumaco.pdf  2018
# 1  AT N° 004-18 NAR-Tumaco.pdf  2018
# 2  AT N° 004-18 NAR-Tumaco.pdf  2018
# 3  AT N° 004-18 NAR-Tumaco.pdf  2018
# 4  AT N° 004-18 NAR-Tumaco.pdf  2018

# %% [markdown]
# # 3. Functions

# %%
def most_mentioned_actors(actors):           
    data = { 
             'actors': list(Counter(actors).keys()), 
             'frequency': list(Counter(actors).values())
           }

    counterdf = pd.DataFrame(data)
    counterdf = counterdf.groupby('actors').agg({'frequency' : 'sum'}).sort_values('frequency', ascending = False)
    return counterdf

# %% [markdown]
# # 4. Most mentioned Actors in the text surrounding NNAJ  (at least 6 mentions)

# %%
list_ = df['Clean_NNAJ_actors']
dt = most_mentioned_actors(list_)
dt[dt.frequency>5]
# Out:
#                                                     frequency
# actors
# Fuerzas Armadas Revolucionarias - Ejército Del ...        597
# Ejército De Liberación Nacional                           323
# Autodefensas Unidas De Colombia                           280
# Rastrojos                                                 197
# Grupo Armado Ilegal                                       184
# Águilas Negras                                            182
# Constru                                                   115
# Autodefensas Gaitanistas De Colombia                      114
# Urabeños                                                  107
# Sierra                                                     50
# Unión                                                      49
# Paisas                                                     46
# Cordillera                                                 29
# Frente Primero                                             22
# Grupos Posdesmovilización                                  21
# Grupos Alzados                                             20
# Bandas Criminales                                          16
# Clan Del Golfo                                             16
# Grupos Armados De Crimen Organizado                        14
# Grupos Delictivos Organizados                              13
# Autodefensas Gaitanistas                                   12
# Gaitanistas                                                11
# Frente Cacique Pipintá                                      9
# Norte Del Valle                                             9
# Autodefensas                                                9
# Frente Primero De Las Farc                                  9
# Grupos Armados Irregulares                                  7
# Grupos Armados Organizados                                  7
# Facciones Disidentes De Las Ex Farc                         6
# Jóvenes Por Grupos Armados Organizados                      6
# Bvpa                                                        6
# Clan                                                        6
# Grupos Armados Alzados                                      6

# %%
list(most_mentioned_actors(list_)[:100].index)
# Out:
# ['Fuerzas Armadas Revolucionarias - Ejército Del Pueblo',
#  'Ejército De Liberación Nacional',
#  'Autodefensas Unidas De Colombia',
#  'Rastrojos',
#  'Grupo Armado Ilegal',
#  'Águilas Negras',
#  'Constru',
#  'Autodefensas Gaitanistas De Colombia',
#  'Urabeños',
#  'Sierra',
#  'Unión',
#  'Paisas',
#  'Cordillera',
#  'Frente Primero',
#  'Grupos Posdesmovilización',
#  'Grupos Alzados',
#  'Bandas Criminales',
#  'Clan Del Golfo',
#  'Grupos Armados De Crimen Organizado',
#  'Grupos Delictivos Organizados',
#  'Autodefensas Gaitanistas',
#  'Gaitanistas',
#  'Al Instituto Colombiano',
#  'Frente Primero De Las Farc',
#  'De',
#  'Norte Del Valle',
#  'Autodefensas',
#  'Frente Cacique Pipintá',
#  'Corte',
#  'Alcaldías Municipales',
#  'Instituto Colombiano',
#  'Fuerza Publica',
#  'Srpa',
#  'Niñas Adolescentes Y',
#  'Consejo De Seguridad',
#  'Armada Nacional',
#  'Sede Central Calle 55 No',
#  'Ejercito Nacional',
#  'Fiscalía',
#  'Generaciones Con Bienestar',
#  'Sijin',
#  'Prevención Del Reclutamiento',
#  'Ruuvs',
#  'Fuerzas Armadas',
#  'Organismos De Seguridad Del Estado',
#  'Fuerza',
#  'Qu',
#  'Pastoral Social',
#  'Comisión Intersectorial De Alertas Tempranas',
#  'Agencia Para La Reincorporación Y La Normalización',
#  'Protección Social',
#  'Procesosubproceso Prevención Y Protección Código Ppp01 F10',
#  'Grupos Armados Organizados',
#  'Sat Código Dprpc04 Versión Última',
#  'Carmen',
#  'Acnur',
#  'Grupos Armados Irregulares',
#  'Cooperación Internacional',
#  'Gobernación Del Meta',
#  'Resolución A',
#  'Bvpa',
#  'Red Nacional De Información',
#  'Líderes',
#  'Ciprat',
#  'Facciones Disidentes',
#  'Sat Código Dprfto07 Versión Final Página',
#  'Al Ministerio De Defensa Nacional',
#  'Al Instituto Colombiano De Bienestar Familia R',
#  'Clan',
#  'Alcaldías Municipales De Bucaramanga',
#  'Unidad De Atención',
#  'Dirección Para La Acción Integral Contra Minas Antipersonal',
#  'A',
#  'Rni',
#  'Secretaria Departamental De Educación',
#  'Gobernación Del Huila',
#  'Formato Nota De Seguimiento',
#  'Organización Internacional Del Trabajo',
#  'Infantería De Marina',
#  'Ciprunna',
#  'Grupos Armados Alzados',
#  'Estación',
#  'Comisión Intersectorial De Prevención De Reclutamiento',
#  'Secretario General',
#  'Asamblea General De La Onu',
#  'Al',
#  'Facciones Disidentes De Las Ex Farc',
#  'Jóvenes Por Grupos Armados Organizados',
#  'Unidad De Restitución De Tierras',
#  'Policía Judicial',
#  'Al Gobierno Nacional',
#  'Conflicto',
#  'Conflicto Armado',
#  'Educación',
#  'Nbi',
#  'Unión Peneya',
#  'Departamento Para La Prosperidad Social',
#  'Miembros',
#  'Policía Departamental De Arauca',
#  'Secretaría Técnica']
