# %% [markdown]
# # 1. Installs, Imports and Settings

# %%
#!pip install spacy==3.1.1 
#restart runtime after this
#!python -m spacy download es_core_news_lg

import spacy
nlp = spacy.load("es_core_news_lg")

import csv
import pandas as pd
pd.options.display.max_rows
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# #  2. Reading files

# %%
df = pd.read_csv('data/alertas.csv', sep="|")
df = df[df["Text"].notnull()]
print("Size of Data:", len(df))
print()
print("Columns : ", list(df.columns))
# Out:
# Size of Data: 666
#
# Columns :  ['Filename', 'Text', 'Type', 'Year']

# %%
' '.join(df["Text"]).split()

# %%
len(' '.join(df["Text"]).split())
# Out:
# 4602954

# %%
import re
exceptions = [
    "SAT \n \nSede Central Calle 55 Nº 10 32 Of 115 \nTels 3147300 Ext 2437 Telefax 6915300 \nEmail", 
    "DE LA", 
    "NI OTRO", 
    "Tels 3147300 Ext 2437 Telefax 6915300", 
    "Ext 2437 Telefax 6915300", 
    "Tels 3147300 Ext 2437 Telefax 6915300", 
    "Sede Central Calle 55 No", 
    "Tels 3147300 Ext 2437 Telefax 6915300", 
    "SAT Sede Central Calle 55 Nº 10 32 Of 115 Email", 
    "SAT Sede Central Calle 55 Nº 1032 Of 115 Email", 
    "SA Email",
    "SAT INFORME DE RIESGO No",
    "DEL CONFLICTO ARMADO Sistema",
    "LA VIDA LA LIBERTAD Y",
    "DELEGADA PARA LA EVALUACIÓN DEL RIESGO POBLACIÓN CIVIL",
    "SAT Sede Central Calle 55 Nº 1032 Of 115 Tels 3147300 Ext 2437 Telefax 6915300 Email", 
    "SAT Sede Central Calle 55 Nº 10 32 Of 115 Tels 3147300 Ext 2437 Telefax 6915300 Email", 
    "INFORME DE RIESGO No", 
    "LA INTEGRIDAD FISICA DE LA POBLACIÓN", 
    "Tels 3147300 Ext 2437 Telefax", 
    "DELEGADA PARA LA EVALUACIÓN", 
    "LA POBLACIÓN CIVIL", 
    "Tels 3147300 Ext 2437 Telefax 6915300 Correo Electrónico", 
    "VILLEGAS Defensor Delegado",
    "Tels 3147300 Ext 2452 Telefax",
    "2437 Telefax",
    "CHACÓN Defensor Delegado", 
    "Tels 3147300 ext 24372464 Fax ext 2452 Bogotá",
    "Tels 3147300 Ext 2437 Telefax ext", 
    "Tels 3147300 Ext 2452 Telefax", 
    "Telefax Ext 2452 Correo Electrónico", 
    "2437 Telefax", 
    "Tels 3147300 ext 24372464 Fax ext 2452 Bogotá", 
    "2464 Fax ext 2452 Bogotá",
    "X", 
    "Inminencia alta Urgente Grado 2 Urgencia intermedia Grado 3 No", 
    "SAT Sede Central Calle 55 Nº 1032 Bloque C Tercer piso Tels 3147300 Ext 2437 Telefax", 
    "O SITUACIÓN CRÓNICA",
    "AUTORIDADES VINCULADAS AL", 
    
    
]
def cleantext1(text):
    text = text.lower()
    text = text.replace("\n", " ")
    for s in exceptions:
        text = text.replace(s.lower(), " ")
    text = re.sub(' +', ' ', text)
    return text    

df["Text"] = df["Text"].apply(cleantext1)

# %% [markdown]
# # 3. Functions

# %%
def acrfull(x):
    return ': '.join([x, spacy.explain(x)])

def extract_named_entities(text):    
    nlp.max_length = len(text) + 100
    doc = nlp(text)

    dt = pd.DataFrame(columns=['entity', 'label'])
    i = 0
    for ent in doc.ents:
        if ent.text not in exceptions:
            dt.loc[i] = [ent.text, ent.label_] 
            i = i +1
        
    dt = dt.reset_index()
    dt = dt.groupby(['entity', 'label']).agg({'index' : 'count'}).sort_values('index', ascending=False).reset_index()
    dt.columns = ['Entity', 'Type', '#Ocurrences']
    dt = dt.set_index('Entity')
    dt['Type'] = dt['Type'].apply(acrfull)
    
    dt = dt.sort_values('#Ocurrences', ascending=False) #sort before deleting duplicates
    dt = dt[~dt.index.duplicated(keep='first')]                 
    
    #recognizing handlers
    dt.loc[dt.index.str.startswith('@') , 'Type'] = 'Social Media Handler'
    
    return dt.sort_values('#Ocurrences', ascending=False)

# %% [markdown]
# # 4. Top 20 named entities by Year - Advertencias

# %%
years = list(df[df["Type"] == "advertencia"]['Year'].unique())
years = sorted(years)
years
# Out:
# [2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2018,
#  2019,
#  2020,
#  2021,
#  2022]

# %%
for y in years:
    dfg = df[(df["Type"] == "advertencia") & (df["Year"] == y)]
    print(y,"--", len(dfg), "documents")
    dt = extract_named_entities(' '.join(dfg['Text'])).head(20)
    display(dt)
# Out:
# 2002 -- 27 documents
#                                                                                                             Type  \
# Entity
# sat                                                                 ORG: Companies, agencies, institutions, etc.
# eln                           MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# farc                                                                ORG: Companies, agencies, institutions, etc.
# medellín                                                LOC: Non-GPE locations, mountain ranges, bodies of water
# farc eln auc                  MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# antioquia                                               LOC: Non-GPE locations, mountain ranges, bodies of water
# magdalena                                               LOC: Non-GPE locations, mountain ranges, bodies of water
# farc eln                      MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# valledupar                                              LOC: Non-GPE locations, mountain ranges, bodies of water
# sierra nevada de santa marta                            LOC: Non-GPE locations, mountain ranges, bodies of water
# tenerife                                                LOC: Non-GPE locations, mountain ranges, bodies of water
# bogotá dc colombia                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# provincia del sumapaz                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# sucre                                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# ciénaga del opón                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# santa cruz                                              LOC: Non-GPE locations, mountain ranges, bodies of water
# qu                                                                  ORG: Companies, agencies, institutions, etc.
# heredia                                                 LOC: Non-GPE locations, mountain ranges, bodies of water
# río magdalena                                           LOC: Non-GPE locations, mountain ranges, bodies of water
# guerrilla s farc                                                    ORG: Companies, agencies, institutions, etc.
#
#                               #Ocurrences
# Entity
# sat                                    82
# eln                                    55
# farc                                   54
# medellín                               22
# farc eln auc                           19
# antioquia                              15
# magdalena                              12
# farc eln                                8
# valledupar                              7
# sierra nevada de santa marta            7
# tenerife                                6
# bogotá dc colombia                      6
# provincia del sumapaz                   6
# sucre                                   6
# ciénaga del opón                        6
# santa cruz                              5
# qu                                      5
# heredia                                 5
# río magdalena                           4
# guerrilla s farc                        4
# 2003 -- 58 documents
#                                                                                                   Type  \
# Entity
# farc                                                      ORG: Companies, agencies, institutions, etc.
# sat                                                       ORG: Companies, agencies, institutions, etc.
# eln                 MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# dc colombia                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# farc eln auc        MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# bogotá dc colombia                            LOC: Non-GPE locations, mountain ranges, bodies of water
# antioquia                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# san miguel                                    LOC: Non-GPE locations, mountain ranges, bodies of water
# bajo putumayo                                 LOC: Non-GPE locations, mountain ranges, bodies of water
# córdoba                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# santander                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# sucre                                         LOC: Non-GPE locations, mountain ranges, bodies of water
# s farc                                                    ORG: Companies, agencies, institutions, etc.
# boyacá                                                                    PER: Named person or family.
# san francisco                                 LOC: Non-GPE locations, mountain ranges, bodies of water
# medellín                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# panamá                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# valle del guamuez                             LOC: Non-GPE locations, mountain ranges, bodies of water
# magdalena                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# argelia                                       LOC: Non-GPE locations, mountain ranges, bodies of water
#
#                     #Ocurrences
# Entity
# farc                        169
# sat                         120
# eln                          89
# dc colombia                  51
# farc eln auc                 39
# bogotá dc colombia           26
# antioquia                    23
# san miguel                   22
# bajo putumayo                19
# córdoba                      16
# santander                    16
# sucre                        15
# s farc                       15
# boyacá                       14
# san francisco                14
# medellín                     14
# panamá                       13
# valle del guamuez            13
# magdalena                    13
# argelia                      13
# 2004 -- 88 documents
#                                                                                                                       Type  \
# Entity
# farc                                                                          ORG: Companies, agencies, institutions, etc.
# dc colombia                                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# eln                                     MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# bogotá dc colombia                                                LOC: Non-GPE locations, mountain ranges, bodies of water
# arauca                                                            LOC: Non-GPE locations, mountain ranges, bodies of water
# ciat                                                              LOC: Non-GPE locations, mountain ranges, bodies of water
# oea                                                                           ORG: Companies, agencies, institutions, etc.
# santander                                                         LOC: Non-GPE locations, mountain ranges, bodies of water
#  a no ser                              MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# s farc                                                                        ORG: Companies, agencies, institutions, etc.
# venezuela                                                         LOC: Non-GPE locations, mountain ranges, bodies of water
# tibú                                                              LOC: Non-GPE locations, mountain ranges, bodies of water
#  a la vida  a la integridad personal  MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# córdoba                                                           LOC: Non-GPE locations, mountain ranges, bodies of water
# bucaramanga                                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# sat                                                                           ORG: Companies, agencies, institutions, etc.
#  a la libertad                         MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# san juan                                                          LOC: Non-GPE locations, mountain ranges, bodies of water
# antioquia                                                         LOC: Non-GPE locations, mountain ranges, bodies of water
# magdalena                                                         LOC: Non-GPE locations, mountain ranges, bodies of water
#
#                                         #Ocurrences
# Entity
# farc                                            472
# dc colombia                                     158
# eln                                             139
# bogotá dc colombia                              134
# arauca                                          113
# ciat                                             66
# oea                                              65
# santander                                        58
#  a no ser                                       45
# s farc                                           39
# venezuela                                        38
# tibú                                             38
#  a la vida  a la integridad personal           37
# córdoba                                          36
# bucaramanga                                      33
# sat                                              31
#  a la libertad                                  31
# san juan                                         28
# antioquia                                        26
# magdalena                                        25
# 2005 -- 65 documents
#                                                                                                     Type  \
# Entity
# farc                                                        ORG: Companies, agencies, institutions, etc.
# eln                   MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# bogotá dc colombia                              LOC: Non-GPE locations, mountain ranges, bodies of water
# dc colombia                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# sat                                                         ORG: Companies, agencies, institutions, etc.
# arauca                                          LOC: Non-GPE locations, mountain ranges, bodies of water
# magdalena                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# ciat                                            LOC: Non-GPE locations, mountain ranges, bodies of water
# argelia                                         LOC: Non-GPE locations, mountain ranges, bodies of water
# dario mejia villegas                                                        PER: Named person or family.
#  a no ser            MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# oea                                                         ORG: Companies, agencies, institutions, etc.
# colombia                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# incoder               MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# s farc                                                      ORG: Companies, agencies, institutions, etc.
# florida                                         LOC: Non-GPE locations, mountain ranges, bodies of water
# córdoba                                         LOC: Non-GPE locations, mountain ranges, bodies of water
# santander                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# cundinamarca                                    LOC: Non-GPE locations, mountain ranges, bodies of water
# albania                                         LOC: Non-GPE locations, mountain ranges, bodies of water
#
#                       #Ocurrences
# Entity
# farc                          354
# eln                           117
# bogotá dc colombia            113
# dc colombia                    97
# sat                            79
# arauca                         73
# magdalena                      51
# ciat                           49
# argelia                        41
# dario mejia villegas           41
#  a no ser                     35
# oea                            35
# colombia                       33
# incoder                        33
# s farc                         32
# florida                        31
# córdoba                        31
# santander                      29
# cundinamarca                   26
# albania                        26
# 2006 -- 52 documents
#                                                                                                            Type  \
# Entity
# farc                                                               ORG: Companies, agencies, institutions, etc.
# bogotá dc colombia                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# eln                          MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# dc colombia                                            LOC: Non-GPE locations, mountain ranges, bodies of water
# antioquia                                              LOC: Non-GPE locations, mountain ranges, bodies of water
# santander                                              LOC: Non-GPE locations, mountain ranges, bodies of water
# arauca                                                 LOC: Non-GPE locations, mountain ranges, bodies of water
# valle del cauca                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# ciat                                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# magdalena                                              LOC: Non-GPE locations, mountain ranges, bodies of water
# sat                                                                ORG: Companies, agencies, institutions, etc.
# bogotá                                                 LOC: Non-GPE locations, mountain ranges, bodies of water
# c of 304 bogotá dc colombia  MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# florencia                                              LOC: Non-GPE locations, mountain ranges, bodies of water
# medellín                                               LOC: Non-GPE locations, mountain ranges, bodies of water
# s farc                                                             ORG: Companies, agencies, institutions, etc.
# bucaramanga                                            LOC: Non-GPE locations, mountain ranges, bodies of water
# colombia                                               LOC: Non-GPE locations, mountain ranges, bodies of water
# incoder                      MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# oea                                                                ORG: Companies, agencies, institutions, etc.
#
#                              #Ocurrences
# Entity
# farc                                 291
# bogotá dc colombia                   177
# eln                                  118
# dc colombia                           99
# antioquia                             64
# santander                             54
# arauca                                46
# valle del cauca                       45
# ciat                                  43
# magdalena                             39
# sat                                   37
# bogotá                                36
# c of 304 bogotá dc colombia           35
# florencia                             35
# medellín                              31
# s farc                                30
# bucaramanga                           30
# colombia                              30
# incoder                               29
# oea                                   28
# 2007 -- 36 documents
#                                                                                                                Type  \
# Entity
# farc                                                                   ORG: Companies, agencies, institutions, etc.
# bogotá dc colombia                                         LOC: Non-GPE locations, mountain ranges, bodies of water
# dc colombia                                                LOC: Non-GPE locations, mountain ranges, bodies of water
# eln                              MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# santander                                                  LOC: Non-GPE locations, mountain ranges, bodies of water
# tels 3147300                     MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# colombia                                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# jorge enrique calero                                                                   PER: Named person or family.
#                                                                                       PER: Named person or family.
# bucaramanga                                                LOC: Non-GPE locations, mountain ranges, bodies of water
# magdalena                                                  LOC: Non-GPE locations, mountain ranges, bodies of water
# antioquia                                                  LOC: Non-GPE locations, mountain ranges, bodies of water
# tolima                                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# nariño                                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# medellín                                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# guerrilla s farc                                                       ORG: Companies, agencies, institutions, etc.
# sucre                                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# autodefensas unidas de colombia                                        ORG: Companies, agencies, institutions, etc.
# de colombia                                                LOC: Non-GPE locations, mountain ranges, bodies of water
# san onofre                                                 LOC: Non-GPE locations, mountain ranges, bodies of water
#
#                                  #Ocurrences
# Entity
# farc                                     225
# bogotá dc colombia                       180
# dc colombia                              178
# eln                                      111
# santander                                 81
# tels 3147300                              65
# colombia                                  48
# jorge enrique calero                      43
#                                          39
# bucaramanga                               39
# magdalena                                 35
# antioquia                                 34
# tolima                                    34
# nariño                                    31
# medellín                                  31
# guerrilla s farc                          30
# sucre                                     28
# autodefensas unidas de colombia           28
# de colombia                               27
# san onofre                                26
# 2008 -- 31 documents
#                                                                                                   Type  \
# Entity
# dc colombia                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# farc                                                      ORG: Companies, agencies, institutions, etc.
# eln                 MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# arauca                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# tels 3147300        MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# bogotá dc colombia                            LOC: Non-GPE locations, mountain ranges, bodies of water
# santander                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# san juan                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# colombia                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# barranquilla                                  LOC: Non-GPE locations, mountain ranges, bodies of water
# antioquia                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# venezuela                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# córdoba                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# guerrilla s farc                                          ORG: Companies, agencies, institutions, etc.
# el tarra                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# nariño                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# corinto                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# de colombia                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# tibú                                          LOC: Non-GPE locations, mountain ranges, bodies of water
# sincelejo                                     LOC: Non-GPE locations, mountain ranges, bodies of water
#
#                     #Ocurrences
# Entity
# dc colombia                 280
# farc                        193
# eln                          85
# arauca                       68
# tels 3147300                 48
# bogotá dc colombia           47
# santander                    43
# san juan                     39
# colombia                     38
# barranquilla                 37
# antioquia                    33
# venezuela                    33
# córdoba                      33
# guerrilla s farc             32
# el tarra                     32
# nariño                       31
# corinto                      29
# de colombia                  29
# tibú                         28
# sincelejo                    27
# 2009 -- 30 documents
#                                                                                                     Type  \
# Entity
# bogotá dc colombia                              LOC: Non-GPE locations, mountain ranges, bodies of water
# farc                                                        ORG: Companies, agencies, institutions, etc.
# colombia                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# antioquia                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# eln                   MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# dc colombia                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# córdoba                                         LOC: Non-GPE locations, mountain ranges, bodies of water
# valledupar                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# bajo cauca                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# arauca                                          LOC: Non-GPE locations, mountain ranges, bodies of water
# santa marta                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# maicao                                          LOC: Non-GPE locations, mountain ranges, bodies of water
# de colombia                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# bucaramanga                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# caribe                                          LOC: Non-GPE locations, mountain ranges, bodies of water
# santander                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# magdalena                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# caldas                                          LOC: Non-GPE locations, mountain ranges, bodies of water
# guerrilla s farc                                            ORG: Companies, agencies, institutions, etc.
# san josé de apartadó                            LOC: Non-GPE locations, mountain ranges, bodies of water
#
#                       #Ocurrences
# Entity
# bogotá dc colombia            242
# farc                          118
# colombia                      114
# antioquia                      96
# eln                            91
# dc colombia                    88
# córdoba                        66
# valledupar                     60
# bajo cauca                     50
# arauca                         48
# santa marta                    48
# maicao                         44
# de colombia                    44
# bucaramanga                    44
# caribe                         40
# santander                      38
# magdalena                      36
# caldas                         34
# guerrilla s farc               34
# san josé de apartadó           33
# 2010 -- 18 documents
#                                                                                                   Type  \
# Entity
# dc colombia                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# medellín                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# bogotá dc colombia                            LOC: Non-GPE locations, mountain ranges, bodies of water
# farc                                                      ORG: Companies, agencies, institutions, etc.
# san juan                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# villavicencio                                 LOC: Non-GPE locations, mountain ranges, bodies of water
# uribia                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# cauca                                         LOC: Non-GPE locations, mountain ranges, bodies of water
# tels 3147300        MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# pablo                                                                     PER: Named person or family.
#                                                                          PER: Named person or family.
# erpac                                         LOC: Non-GPE locations, mountain ranges, bodies of water
# sipí                                          LOC: Non-GPE locations, mountain ranges, bodies of water
# eln                 MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# de colombia                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# colombia                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# antioquia                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# caloto                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# bogotá                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# san miguel                                    LOC: Non-GPE locations, mountain ranges, bodies of water
#
#                     #Ocurrences
# Entity
# dc colombia                 164
# medellín                    151
# bogotá dc colombia          126
# farc                        125
# san juan                     51
# villavicencio                44
# uribia                       41
# cauca                        34
# tels 3147300                 33
# pablo                        32
#                             30
# erpac                        30
# sipí                         29
# eln                          29
# de colombia                  28
# colombia                     28
# antioquia                    26
# caloto                       24
# bogotá                       24
# san miguel                   22
# 2011 -- 17 documents
#                                                                                                   Type  \
# Entity
# dc colombia                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# farc                                                      ORG: Companies, agencies, institutions, etc.
# eln                 MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# bogotá dc colombia                            LOC: Non-GPE locations, mountain ranges, bodies of water
# acandí                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# unguía                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# cravo norte                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# tiquisio                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# cundinamarca                                  LOC: Non-GPE locations, mountain ranges, bodies of water
# algeciras                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# arauca                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# loba                                          LOC: Non-GPE locations, mountain ranges, bodies of water
# cabrera                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# de colombia                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# antioquia                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# santander                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# córdoba                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# villa del rosario                             LOC: Non-GPE locations, mountain ranges, bodies of water
# cúcuta                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# ayapel                                        LOC: Non-GPE locations, mountain ranges, bodies of water
#
#                     #Ocurrences
# Entity
# dc colombia                 199
# farc                        128
# eln                          78
# bogotá dc colombia           45
# acandí                       45
# unguía                       42
# cravo norte                  39
# tiquisio                     30
# cundinamarca                 30
# algeciras                    30
# arauca                       27
# loba                         27
# cabrera                      26
# de colombia                  25
# antioquia                    24
# santander                    24
# córdoba                      22
# villa del rosario            22
# cúcuta                       21
# ayapel                       21
# 2012 -- 27 documents
#                                                                                                   Type  \
# Entity
# farc                                                      ORG: Companies, agencies, institutions, etc.
# dc colombia                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# eln                 MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# bogotá dc colombia                            LOC: Non-GPE locations, mountain ranges, bodies of water
# florida                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# san martín                                    LOC: Non-GPE locations, mountain ranges, bodies of water
# antioquia                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# granada                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# valle del cauca                               LOC: Non-GPE locations, mountain ranges, bodies of water
# segovia                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# miranda                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# guerrilla s farc                                          ORG: Companies, agencies, institutions, etc.
# colombia                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# sat                                                       ORG: Companies, agencies, institutions, etc.
# tolima                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# puerto gaitán                                 LOC: Non-GPE locations, mountain ranges, bodies of water
# zaragoza                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# santander                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# barrancabermeja                               LOC: Non-GPE locations, mountain ranges, bodies of water
# venezuela                                     LOC: Non-GPE locations, mountain ranges, bodies of water
#
#                     #Ocurrences
# Entity
# farc                        270
# dc colombia                 266
# eln                         106
# bogotá dc colombia          101
# florida                      79
# san martín                   61
# antioquia                    61
# granada                      60
# valle del cauca              58
# segovia                      52
# miranda                      51
# guerrilla s farc             49
# colombia                     48
# sat                          47
# tolima                       46
# puerto gaitán                46
# zaragoza                     46
# santander                    45
# barrancabermeja              44
# venezuela                    41
# 2013 -- 5 documents
#                                                                                                               Type  \
# Entity
# sincelejo                                                 LOC: Non-GPE locations, mountain ranges, bodies of water
# san juan                                                  LOC: Non-GPE locations, mountain ranges, bodies of water
# bogotá                                                    LOC: Non-GPE locations, mountain ranges, bodies of water
# río san juan                                              LOC: Non-GPE locations, mountain ranges, bodies of water
# risaralda                                                 LOC: Non-GPE locations, mountain ranges, bodies of water
# santa cecilia                                             LOC: Non-GPE locations, mountain ranges, bodies of water
# farc                                                                  ORG: Companies, agencies, institutions, etc.
# eln                             MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# sat                                                                   ORG: Companies, agencies, institutions, etc.
# aurelio rodríguez s farc                                                              PER: Named person or family.
# chamí                                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# jorge enrique calero                                                                  PER: Named person or family.
# togoromá                                                  LOC: Non-GPE locations, mountain ranges, bodies of water
# san luis san isidro i y ii                                LOC: Non-GPE locations, mountain ranges, bodies of water
# dih                                                                                   PER: Named person or family.
# corregimiento de santa cecilia                            LOC: Non-GPE locations, mountain ranges, bodies of water
# cundinamarca                                              LOC: Non-GPE locations, mountain ranges, bodies of water
# sat 1 calle 55                  MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# marruecos                                                 LOC: Non-GPE locations, mountain ranges, bodies of water
# dane                            MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
#
#                                 #Ocurrences
# Entity
# sincelejo                                31
# san juan                                 23
# bogotá                                   13
# río san juan                             12
# risaralda                                 9
# santa cecilia                             9
# farc                                      8
# eln                                       7
# sat                                       6
# aurelio rodríguez s farc                  5
# chamí                                     5
# jorge enrique calero                      5
# togoromá                                  5
# san luis san isidro i y ii                4
# dih                                       4
# corregimiento de santa cecilia            4
# cundinamarca                              4
# sat 1 calle 55                            4
# marruecos                                 4
# dane                                      3
# 2018 -- 59 documents
#                                                                                                Type  \
# Entity
# eln              MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# bogotá                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# ciprat                                                                 PER: Named person or family.
# colombia                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# sat                                                    ORG: Companies, agencies, institutions, etc.
# farc                                                   ORG: Companies, agencies, institutions, etc.
# farc ep                                                ORG: Companies, agencies, institutions, etc.
# antioquia                                  LOC: Non-GPE locations, mountain ranges, bodies of water
# arauca                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# córdoba                                    LOC: Non-GPE locations, mountain ranges, bodies of water
# florida                                    LOC: Non-GPE locations, mountain ranges, bodies of water
# caloto                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# corinto                                    LOC: Non-GPE locations, mountain ranges, bodies of water
# granada                                    LOC: Non-GPE locations, mountain ranges, bodies of water
# cauca                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# san josé de uré                            LOC: Non-GPE locations, mountain ranges, bodies of water
# miraflores                                 LOC: Non-GPE locations, mountain ranges, bodies of water
# san martín                                 LOC: Non-GPE locations, mountain ranges, bodies of water
# mauricio                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# ppp02            MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
#
#                  #Ocurrences
# Entity
# eln                      387
# bogotá                   291
# ciprat                   215
# colombia                 195
# sat                      180
# farc                     150
# farc ep                  109
# antioquia                102
# arauca                    91
# córdoba                   77
# florida                   76
# caloto                    74
# corinto                   74
# granada                   71
# cauca                     68
# san josé de uré           64
# miraflores                62
# san martín                60
# mauricio                  59
# ppp02                     59
# 2019 -- 51 documents
#                                                                                          Type  \
# Entity
# eln        MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# bogotá                               LOC: Non-GPE locations, mountain ranges, bodies of water
# antioquia                            LOC: Non-GPE locations, mountain ranges, bodies of water
# farc                                             ORG: Companies, agencies, institutions, etc.
# ciprat                                                           PER: Named person or family.
# ppp02      MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# ppp01      MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# santander                            LOC: Non-GPE locations, mountain ranges, bodies of water
# sat                                              ORG: Companies, agencies, institutions, etc.
# colombia                             LOC: Non-GPE locations, mountain ranges, bodies of water
# arauca                               LOC: Non-GPE locations, mountain ranges, bodies of water
# venezuela                            LOC: Non-GPE locations, mountain ranges, bodies of water
# medellín                             LOC: Non-GPE locations, mountain ranges, bodies of water
# córdoba                              LOC: Non-GPE locations, mountain ranges, bodies of water
# valdivia                             LOC: Non-GPE locations, mountain ranges, bodies of water
# farc ep                                          ORG: Companies, agencies, institutions, etc.
# san juan                             LOC: Non-GPE locations, mountain ranges, bodies of water
# dabeiba                              LOC: Non-GPE locations, mountain ranges, bodies of water
# cauca                                LOC: Non-GPE locations, mountain ranges, bodies of water
# quinchía                             LOC: Non-GPE locations, mountain ranges, bodies of water
#
#            #Ocurrences
# Entity
# eln                734
# bogotá             366
# antioquia          234
# farc               213
# ciprat             199
# ppp02              160
# ppp01              159
# santander          147
# sat                142
# colombia           135
# arauca             116
# venezuela          112
# medellín            95
# córdoba             94
# valdivia            86
# farc ep             82
# san juan            82
# dabeiba             82
# cauca               82
# quinchía            79
# 2020 -- 54 documents
#                                                                                              Type  \
# Entity
# ppp01          MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# eln            MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# bogotá                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# medellín                                 LOC: Non-GPE locations, mountain ranges, bodies of water
# antioquia                                LOC: Non-GPE locations, mountain ranges, bodies of water
# bajo cauca                               LOC: Non-GPE locations, mountain ranges, bodies of water
# cauca                                    LOC: Non-GPE locations, mountain ranges, bodies of water
# farc ep                                              ORG: Companies, agencies, institutions, etc.
# ciprat                                                               PER: Named person or family.
# uribe                                    LOC: Non-GPE locations, mountain ranges, bodies of water
# sat                                                  ORG: Companies, agencies, institutions, etc.
# farc                                                 ORG: Companies, agencies, institutions, etc.
# nna                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# colombia                                 LOC: Non-GPE locations, mountain ranges, bodies of water
# argelia                                  LOC: Non-GPE locations, mountain ranges, bodies of water
# puerto gaitán                            LOC: Non-GPE locations, mountain ranges, bodies of water
# santander                                LOC: Non-GPE locations, mountain ranges, bodies of water
# buenos aires                             LOC: Non-GPE locations, mountain ranges, bodies of water
# puerto rico                              LOC: Non-GPE locations, mountain ranges, bodies of water
# cáceres                                  LOC: Non-GPE locations, mountain ranges, bodies of water
#
#                #Ocurrences
# Entity
# ppp01                  765
# eln                    522
# bogotá                 338
# medellín               301
# antioquia              236
# bajo cauca             206
# cauca                  189
# farc ep                178
# ciprat                 169
# uribe                  161
# sat                    156
# farc                   151
# nna                    149
# colombia               137
# argelia                125
# puerto gaitán          114
# santander              108
# buenos aires           105
# puerto rico            105
# cáceres                103
# 2021 -- 25 documents
#                                                                                                Type  \
# Entity
# eln              MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# ppp01            MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# farc ep                                                ORG: Companies, agencies, institutions, etc.
# puerto carreño                             LOC: Non-GPE locations, mountain ranges, bodies of water
# ppp02            MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# cravo norte                                LOC: Non-GPE locations, mountain ranges, bodies of water
# arauca                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# colombia                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# antioquia                                  LOC: Non-GPE locations, mountain ranges, bodies of water
# santander                                  LOC: Non-GPE locations, mountain ranges, bodies of water
# farc                                                   ORG: Companies, agencies, institutions, etc.
# bucaramanga                                LOC: Non-GPE locations, mountain ranges, bodies of water
# pp p02 f10       MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# ciprat                                                                 PER: Named person or family.
# venezuela                                  LOC: Non-GPE locations, mountain ranges, bodies of water
# amazonas                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# valle del cauca                            LOC: Non-GPE locations, mountain ranges, bodies of water
# putumayo                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# puerto guzmán                              LOC: Non-GPE locations, mountain ranges, bodies of water
# san juan                                   LOC: Non-GPE locations, mountain ranges, bodies of water
#
#                  #Ocurrences
# Entity
# eln                      430
# ppp01                    417
# farc ep                  140
# puerto carreño           133
# ppp02                    121
# cravo norte              115
# arauca                   111
# colombia                 107
# antioquia                100
# santander                 99
# farc                      98
# bucaramanga               98
# pp p02 f10                96
# ciprat                    89
# venezuela                 88
# amazonas                  84
# valle del cauca           81
# putumayo                  80
# puerto guzmán             80
# san juan                  74
# 2022 -- 14 documents
#                                                                                                 Type  \
# Entity
# eln               MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# ppp01             MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# farc                                                    ORG: Companies, agencies, institutions, etc.
# cali                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# gdo               MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# farc ep                                                 ORG: Companies, agencies, institutions, etc.
# valle del cauca                             LOC: Non-GPE locations, mountain ranges, bodies of water
# antioquia                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# · bogotá                                    LOC: Non-GPE locations, mountain ranges, bodies of water
# colombia                                    LOC: Non-GPE locations, mountain ranges, bodies of water
# santander                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# santiago de cali                            LOC: Non-GPE locations, mountain ranges, bodies of water
# bogotá                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# venecia                                     LOC: Non-GPE locations, mountain ranges, bodies of water
# sat                                                     ORG: Companies, agencies, institutions, etc.
# leguízamo                                   LOC: Non-GPE locations, mountain ranges, bodies of water
# ciprat                                                                  PER: Named person or family.
# titiribí                                    LOC: Non-GPE locations, mountain ranges, bodies of water
# vulneratorias                                                           PER: Named person or family.
# cundinamarca                                LOC: Non-GPE locations, mountain ranges, bodies of water
#
#                   #Ocurrences
# Entity
# eln                       345
# ppp01                     276
# farc                      225
# cali                      198
# gdo                       115
# farc ep                   113
# valle del cauca           107
# antioquia                  99
# · bogotá                   90
# colombia                   74
# santander                  66
# santiago de cali           54
# bogotá                     54
# venecia                    52
# sat                        51
# leguízamo                  48
# ciprat                     47
# titiribí                   44
# vulneratorias              42
# cundinamarca               42

# %% [markdown]
# # 5 Top 20 named entities in Seguimiento

# %%
for y in [2018, 2019]:
    print (y)
    dfg = df[(df["Type"] == "seguimiento") & (df["Year"] == y)]
    dt = extract_named_entities(' '.join(dfg['Text'])).head(20)
    display(dt)
# Out:
# 2018
#                                                                                                                  Type  \
# Entity
# suarez                                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# ntc gp1000                         MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# córdoba                                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# cauca                                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# jaime orlando                                                                            PER: Named person or family.
# lazona                                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# caldas                                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# anserma                                                                                  PER: Named person or family.
# ciprat                                                                                   PER: Named person or family.
# bureau                                                                   ORG: Companies, agencies, institutions, etc.
# loque                                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# gao                                                                      ORG: Companies, agencies, institutions, etc.
# tlerralta                                                    LOC: Non-GPE locations, mountain ranges, bodies of water
# lapolicía                                                                                PER: Named person or family.
# instituto colombiano de bienestar                                        ORG: Companies, agencies, institutions, etc.
# alaalerta                                                                ORG: Companies, agencies, institutions, etc.
# bogotá                                                       LOC: Non-GPE locations, mountain ranges, bodies of water
# sat                                                                      ORG: Companies, agencies, institutions, etc.
# gutiérrez                                                                                PER: Named person or family.
# sedesprenden                                                                             PER: Named person or family.
#
#                                    #Ocurrences
# Entity
# suarez                                      28
# ntc gp1000                                  22
# córdoba                                     16
# cauca                                       14
# jaime orlando                               14
# lazona                                      14
# caldas                                      12
# anserma                                     12
# ciprat                                      12
# bureau                                      12
# loque                                       12
# gao                                         12
# tlerralta                                   10
# lapolicía                                   10
# instituto colombiano de bienestar            8
# alaalerta                                    8
# bogotá                                       8
# sat                                          8
# gutiérrez                                    8
# sedesprenden                                 8
# 2019
#                                                                                                      Type  \
# Entity
# colombia                                         LOC: Non-GPE locations, mountain ranges, bodies of water
# sat                                                          ORG: Companies, agencies, institutions, etc.
# santander                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# vulneratorias                                                                PER: Named person or family.
# antioquia                                        LOC: Non-GPE locations, mountain ranges, bodies of water
# eln                    MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# s naciones unidas                                            ORG: Companies, agencies, institutions, etc.
# valle del cauca                                  LOC: Non-GPE locations, mountain ranges, bodies of water
# farc                                                         ORG: Companies, agencies, institutions, etc.
# at 026 18              MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art
# san josé de uré                                  LOC: Non-GPE locations, mountain ranges, bodies of water
# cauca                                            LOC: Non-GPE locations, mountain ranges, bodies of water
# unp                                                          ORG: Companies, agencies, institutions, etc.
# tarazá                                           LOC: Non-GPE locations, mountain ranges, bodies of water
# de colombia                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# cundinamarca putumayo                            LOC: Non-GPE locations, mountain ranges, bodies of water
# iván duque                                                                   PER: Named person or family.
# bogotá dc nariño                                 LOC: Non-GPE locations, mountain ranges, bodies of water
# san antonio                                      LOC: Non-GPE locations, mountain ranges, bodies of water
# josé daniel                                                                  PER: Named person or family.
#
#                        #Ocurrences
# Entity
# colombia                        27
# sat                             24
# santander                       23
# vulneratorias                   22
# antioquia                       22
# eln                              9
# s naciones unidas                8
# valle del cauca                  7
# farc                             7
# at 026 18                        7
# san josé de uré                  6
# cauca                            5
# unp                              5
# tarazá                           4
# de colombia                      3
# cundinamarca putumayo            3
# iván duque                       3
# bogotá dc nariño                 3
# san antonio                      3
# josé daniel                      2

# %% [markdown]
# # 5. Exporting to html

# %%
# !jupyter nbconvert --to html 3_NLP_Named_Entities.ipynb
# Out:
# [NbConvertApp] Converting notebook 3_NLP_Named_Entities.ipynb to html
# [NbConvertApp] Writing 652346 bytes to 3_NLP_Named_Entities.html
