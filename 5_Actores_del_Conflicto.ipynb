# %% [markdown]
# # 1. Install, Imports, Settings

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import spacy
from spacy.lang.es.examples import sentences 
#!python -m spacy download es_core_news_md
nlp = spacy.load("es_core_news_md")

# %%
plt.rcParams["figure.figsize"] = [10, 6]
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # 2. Loading data

# %%
df = pd.read_csv("data/alertas.csv", sep="|")

print("Total Number of documents:", len(df))
print("Number of documents with no accesible text (password protected):", len(df[df['Text'].isnull()]))
print("Number of documents with accesible text:",  len(df[df['Text'].notnull()]))
# Out:
# Total Number of documents: 1753
# Number of documents with no accesible text (password protected): 5
# Number of documents with accesible text: 1748

# %%
df.head()
# Out:
#                                             Filename  \
# 0  AT N° 003-18 NAR-Cumbitara, Maguí Payán, Polic...
# 1                        AT N° 004-18 NAR-Tumaco.pdf
# 2                     AT N° 005-18 COR-Tierralta.pdf
# 3                      AT N° 006-18 ARA-Saravena.pdf
# 4  AT N° 007-18 MET-Puerto Lleras, Puerto Rico y ...
#
#                                                 Text          Subtype  \
# 0  Defensoria  \ndel Pueblo  \nCOLOMB IA \n \nBog...  Alerta Temprana
# 1  Defensoría \ndel Pueblo  \nCO LO Mllt  \nCarre...  Alerta Temprana
# 2  Carrera 9  16 21 Bogotá DC  \nPBX 57 1 3147300...  Alerta Temprana
# 3  Defensoría \ndel Pueblo  \nCarrera 9   1621 Bo...  Alerta Temprana
# 4  San Vicente  Bajo \nl  \nMargen  \nIzquierda  ...  Alerta Temprana
#
#           Type  Year                                               Path  \
# 0  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 003-18 NAR-...
# 1  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 004-18 NAR-...
# 2  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 005-18 COR-...
# 3  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 006-18 ARA-...
# 4  Advertencia  2018  data\Advertencia_PDF\AT 2018\AT N° 007-18 MET-...
#
#   Departamento
# 0       Nariño
# 1       Nariño
# 2      Córdoba
# 3       Arauca
# 4         Meta

# %% [markdown]
# # 3. Extracting Actores del Conflicto

# %%
act_dictionary = {
"GAO": "grupo armado organizado"
"GAI": "grupo armado ilegal"
"GAO-r", "grupo armado organizado - residual"
"ELN", "Ejército de Liberación Nacional"
"AGC"," Autodefensas Gaitanistas de Colombia"
"FARC", "Fuerzas Armadas Revolucionarias" 
 "FARC - EP" :"Fuerzas Armadas Revolucionarias Ejército del Pueblo", 
    "EP": "Ejército del Pueblo"
"NNAJ": ["niños", "niñas", "adolescentes", "jóvenes"],
"NNA",
"Carteles", 
"Jalisco Nueva Generación",
"GDO", "Grupo delincuencial organizado"
"Bacrim", "bandas criminales"
"AUC", "Autodefensas Gaitanistas de Colombia"
"Grupos posdesmovilización AUC"
"Clan del Golfo"
"Aguilas Negras"
"EPL"
}
# Out:
#   Input In [18]
#     "GAO", grupo armado organizado
#                  ^
# SyntaxError: invalid syntax

# %%
def extract_actors(text):
    entities  = []
    doc = nlp(text)
    for token in doc:
        print(token.text, token.pos_, token.dep_)    
    return entities
 
txt = df.loc[0]["Text"].lower()
txt = txt.replace("\n", " ")
txt
#df["Actors"] = df["Text"].apply(extract_actors)
# Out:
# 'defensoria   del pueblo   colomb ia    bogotá dc  5 de enero de 2018       doctor   guillermo  rivera  flórez   ministro  del interior   secretaría técnica de la comisión lntersectorial  para la  respuesta rápida a las alertas  tempranas ciprat  carrera 8 no 12 b  31  ciudad       referencia alerta  temprana de  inminencia n º 001 f81 debiclo a la situación  de riesgo  que enfrenta la población  campesina y afrodescendiente d a guenca  del río patía  municipio  de policarpa cumbitara  magüí  payán y roberto  ray el  clepartamento de nariño     respetado señor  ministro  del interior     de manera  atenta  y en concordancia con  lo disruesto en el decreto 2124  de 2017 me permito  remitir  la alerta  temprana de la refere  cia  elfülo  a la inminencia de riesgo de violaciones  a los derechos humanos y de infracci0nes   jh en la que se encuentran los  habitantes de  la  cuenca del río patía municipios  de po ic fpa cumbitara  magüí  payán y roberto  payán  en el  departamento de nariño por la dis u a que libran grupos armados ilegales como el eln  disidencias  de las farc ep y grupos  rmados  posdesmovilización de las auc  con el fin de que  se adopten las medidas de reverción y protección para salvaguardar sus dereehos  fundamentales que  como podl  ción campesina y afrodescendiente de la zona focalizada en  riesgo y que amerita especial protección     los puntos territoriales directamente  afectados hacen parte de la zona ribereña del río patía  así    municipio de policarpa se encuentran en situación de riesgo aproximadamente 3 064  personas de los corregimientos san roque vereda remolino  bajo patía santacruz  veredas santa cruz villa moreno negrital santa rosa las delicias la cuchilla  corregimiento de sánchez  veredas  sánchez  el guadual  el cocal  las palmeras  la cabaña  corales cuyanul la hoja playa menuda las varas en especial situación de riesgo se  encuentran los miembros  del consejo comunitario  para el desarrollo  integral  de las    1 el decreto 2124 del  18 de diciembre de 2017  por el cual se reglamenta et sistema  de prevención y alerta para ta reacción  rápida a la presencia y acciones  yo actividades de las  organizaciones  hechos y conductas criminales que pongan en r iesgo los  derechos de ta población y ta implementación del acuerdo final  para la terminación del conflicto y la construcción de  una paz  estable y durader a define que las alertas tempranas  son e t documento de advertencia de carácter preventivo emitido de  manera autónoma  por ta defensoría del  pueblo artículo  6 en tos casos  que ta entidad  evalúe  que tas circunstanc ias lo ameriten  emitirá  alertas tempranas  bajo el  rótulo de riesgo  de inminencia  artículo 15 las cuales son remitidas  ta secreta ría técnica  de  la comisión lntersectorial  para ta respuesta rápida a las alertas tempranas ciprat quien una vez recibida transmitirá de  forma  inmediata  a las entidades  nacionales  competentes  y a tas autoridades  territoriales para el cumplimiento  de sus funciones  y la adopción de las  medidas necesarias de reacción rápida artículo 11         carrera  9  1621 bogotá dc  pbx  57 1 3147300 línea nacional 01 8000 914814   www defensoria govco   plant illa vigente  desde 27062017      rt v t9  iso 9001 2008  ntc gp 10002009   bureau  veritas   certific1tion   11coii olllu  in llllljiioll s ci     defensoría  del pueblo    col08 1a    comunidades negras de la cordillera occidental copdiconc aproximadamente 2650  personas igualmente integrantes de las juntas de acción comunal representantes de  organizaciones como el movimiento social y político marcha patriótica asociación de  trabajadores campesinos de nariño  astracan dignidad campesina y el comité de  integración del macizo colombiano  cima personas en proceso de reincorporación e  integrantes del partido político fuerza alternativa revolucionaria del común  farc y  autoridades municipales y representantes de entidades estatales que se encuentlía en el  municipio de policarpa    ...

# %%
extract_actors(txt)
# Out:
# defensoria ADJ ROOT
#    SPACE dep
# del ADP case
# pueblo NOUN nmod
#    SPACE dep
# colomb PROPN amod
# ia PROPN appos
#     SPACE dep
# bogotá PROPN amod
# dc PROPN appos
#   SPACE dep
# 5 NUM appos
# de ADP case
# enero NOUN compound
# de ADP case
# 2018 NUM compound
#        SPACE dep
# doctor NOUN amod
#    SPACE dep
# guillermo PROPN appos
#   SPACE dep
# rivera ADJ amod
#   SPACE dep
# flórez NOUN obj
#    SPACE dep
# ministro NOUN obj
#   SPACE dep
# del ADP case
# interior NOUN nmod
#    SPACE dep
# secretaría NOUN appos
# técnica ADJ flat
# de ADP case
# la DET det
# comisión NOUN nmod
# lntersectorial ADJ amod
#   SPACE dep
# para ADP case
# la DET det
#   SPACE dep
# respuesta NOUN nmod
# rápida ADJ amod
# a ADP case
# las DET det
# alertas NOUN nmod
#   SPACE dep
# tempranas ADJ amod
# ciprat NOUN obj
#   SPACE dep
# carrera NOUN nmod
# 8 NUM appos
# no ADV advmod
# 12 NUM nummod
# b NOUN nmod
#   SPACE dep
# 31 NUM nummod
#   SPACE dep
# ciudad NOUN obj
#        SPACE dep
# referencia NOUN obj
# alerta VERB ROOT
#   SPACE dep
# temprana ADJ advmod
# de ADP case
#   SPACE dep
# inminencia ADJ nmod
# n NOUN nmod
# º NOUN nmod
# 001 NUM compound
# f81 VERB advcl
# debiclo NOUN advcl
# a ADP case
# la DET det
# situación NOUN obl
#   SPACE dep
# de ADP case
# riesgo NOUN nmod
#   SPACE dep
# que PRON nsubj
# enfrenta VERB acl
# la DET det
# población NOUN nsubj
#   SPACE dep
# campesina ADJ amod
# y CCONJ cc
# afrodescendiente ADJ conj
# d NOUN amod
# a ADP case
# guenca PROPN obl
#   SPACE dep
# del ADP case
# río NOUN nmod
# patía VERB appos
#   SPACE dep
# municipio NOUN appos
#   SPACE dep
# de ADP case
# policarpa NOUN nmod
# cumbitara VERB advmod
#   SPACE dep
# magüí ADJ obj
#   SPACE dep
# payán ADJ obj
# y CCONJ cc
# roberto PROPN conj
#   SPACE dep
# ray PROPN flat
# el DET det
#   SPACE dep
# clepartamento NOUN nsubj
# de ADP case
# nariño NOUN nmod
#      SPACE dep
# respetado ADJ amod
# señor NOUN obj
#   SPACE dep
# ministro NOUN obj
#   SPACE dep
# del ADP case
# interior NOUN nmod
#      SPACE dep
# de ADP case
# manera NOUN obl
#   SPACE dep
# atenta ADJ conj
#   SPACE dep
# y CCONJ cc
# en ADP case
# concordancia NOUN conj
# con ADP case
#   SPACE dep
# lo PRON det
# disruesto ADJ nmod
# en ADP case
# el DET det
# decreto NOUN obl
# 2124 NUM compound
#   SPACE dep
# de ADP case
# 2017 NOUN nmod
# me PRON iobj
# permito VERB ROOT
#   SPACE dep
# remitir VERB xcomp
#   SPACE dep
# la DET det
# alerta NOUN obj
#   SPACE dep
# temprana ADJ amod
# de ADP case
# la DET det
# refere NOUN nmod
#   SPACE dep
# cia PROPN appos
#   SPACE dep
# elfülo VERB appos
#   SPACE dep
# a ADP case
# la DET det
# inminencia NOUN obj
# de ADP case
# riesgo NOUN nmod
# de ADP case
# violaciones NOUN nmod
#   SPACE dep
# a ADP case
# los DET det
# derechos NOUN nmod
# humanos NOUN compound
# y CCONJ cc
# de ADP case
# infracci0nes NOUN nmod
#    SPACE dep
# jh NOUN conj
# en ADP case
# la DET det
# que PRON obl
# se PRON expl:pv
# encuentran VERB acl
# los DET det
#   SPACE dep
# habitantes NOUN nsubj
# de ADP case
#   SPACE dep
# la DET det
#   SPACE dep
# cuenca NOUN nmod
# del ADP case
# río NOUN nmod
# patía NOUN appos
# municipios NOUN appos
#   SPACE dep
# de ADP case
# po PROPN nmod
# ic PROPN flat
# fpa PROPN flat
# cumbitara VERB advcl
#   SPACE dep
# magüí ADJ obj
#   SPACE dep
# payán ADJ obj
# y CCONJ cc
# roberto NOUN conj
#   SPACE dep
# payán ADJ advmod
#   SPACE dep
# en ADP case
# el DET det
#   SPACE dep
# departamento NOUN obl
# de ADP case
# nariño NOUN nmod
# por ADP case
# la DET det
# dis PROPN nmod
# u CCONJ cc
# a ADP mark
# que SCONJ mark
# libran VERB conj
# grupos NOUN nsubj
# armados ADJ amod
# ilegales ADJ amod
# como SCONJ mark
# el DET det
# eln PROPN obl
#   SPACE dep
# disidencias NOUN amod
#   SPACE dep
# de ADP case
# las DET det
# farc PROPN nmod
# ep NOUN appos
# y CCONJ cc
# grupos NOUN conj
#   SPACE dep
# rmados ADJ amod
#   SPACE dep
# posdesmovilización NOUN obj
# de ADP case
# las DET det
# auc PROPN nmod
#   SPACE dep
# con ADP case
# el DET fixed
# fin NOUN nmod
# de ADP mark
# que SCONJ mark
#   SPACE dep
# se PRON expl:pass
# adopten VERB acl
# las DET det
# medidas NOUN nsubj
# de ADP case
# reverción NOUN nmod
# y CCONJ cc
# protección NOUN conj
# para ADP mark
# salvaguardar VERB acl
# sus DET det
# dereehos NOUN obj
#   SPACE dep
# fundamentales ADJ amod
# que PRON nsubj
#   SPACE dep
# como SCONJ mark
# podl NOUN dep
#   SPACE dep
# ción NOUN obj
# campesina ADJ amod
# y CCONJ cc
# afrodescendiente ADJ conj
# de ADP case
# la DET det
# zona NOUN nmod
# focalizada ADJ amod
# en ADP case
#   SPACE dep
# riesgo NOUN obl
# y CCONJ cc
# que SCONJ mark
# amerita VERB conj
# especial ADJ amod
# protección NOUN obj
#      SPACE dep
# los DET det
# puntos NOUN obj
# territoriales ADJ amod
# directamente ADV advmod
#   SPACE dep
# afectados NOUN amod
# hacen VERB advcl
# parte NOUN compound
# de ADP case
# la DET det
# zona NOUN obj
# ribereña ADJ amod
# del ADP case
# río PROPN nmod
# patía VERB appos
#   SPACE dep
# así ADV advmod
#     SPACE dep
# municipio NOUN nsubj
# de ADP case
# policarpa NOUN nmod
# se PRON expl:pv
# encuentran VERB acl
# en ADP case
# situación NOUN obl
# de ADP case
# riesgo NOUN nmod
# aproximadamente ADV advmod
# 3 NUM nummod
# 064 NUM nummod
#   SPACE dep
# personas NOUN nsubj
# de ADP case
# los DET det
# corregimientos NOUN nmod
# san PROPN flat
# roque PROPN flat
# vereda VERB ccomp
# remolino NOUN obj
#   SPACE dep
# bajo ADP case
# patía NOUN nmod
# santacruz NOUN nmod
#   SPACE dep
# veredas NOUN flat
# santa PROPN appos
# cruz PROPN flat
# villa PROPN flat
# moreno PROPN flat
# negrital ADJ flat
# santa PROPN flat
# rosa PROPN flat
# las DET det
# delicias NOUN obj
# la DET det
# cuchilla NOUN appos
#   SPACE dep
# corregimiento NOUN appos
# de ADP case
# sánchez PROPN nmod
#   SPACE dep
# veredas NOUN flat
#   SPACE dep
# sánchez PROPN flat
#   SPACE dep
# el DET det
# guadual ADJ amod
#   SPACE dep
# el DET det
# cocal VERB obj
#   SPACE dep
# las DET det
# palmeras NOUN appos
#   SPACE dep
# la DET det
# cabaña NOUN obj
#   SPACE dep
# corales NOUN amod
# cuyanul PROPN amod
# la DET det
# hoja PROPN obj
# playa NOUN compound
# menuda ADJ amod
# las DET det
# varas NOUN obj
# en ADP case
# especial ADJ amod
# situación NOUN obl
# de ADP case
# riesgo NOUN nmod
# se PRON expl:pv
#   SPACE dep
# encuentran VERB advcl
# los DET det
# miembros NOUN nsubj
#   SPACE dep
# del ADP case
# consejo NOUN nmod
# comunitario ADJ amod
#   SPACE dep
# para ADP case
# el DET det
# desarrollo NOUN nmod
#   SPACE dep
# integral ADJ amod
#   SPACE dep
# de ADP case
# las DET det
#     SPACE dep
# 1 NUM nmod
# el DET det
# decreto NOUN nsubj
# 2124 NUM compound
# del ADP case
#   SPACE dep
# 18 NUM nmod
# de ADP case
# diciembre NOUN compound
# de ADP case
# 2017 NUM compound
#   SPACE dep
# por ADP case
# el DET det
# cual PRON obl
# se PRON expl:impers
# reglamenta VERB acl
# et PROPN nsubj
# sistema NOUN flat
#   SPACE dep
# de ADP case
# prevención NOUN nmod
# y CCONJ cc
# alerta NOUN conj
# para ADP case
# ta ADJ det
# reacción NOUN obl
#   SPACE dep
# rápida ADJ amod
# a ADP case
# la DET det
# presencia NOUN nmod
# y CCONJ cc
# acciones NOUN conj
#   SPACE dep
# yo PRON nsubj
# actividades NOUN nsubj
# de ADP case
# las DET det
#   SPACE dep
# organizaciones NOUN nmod
#   SPACE dep
# hechos NOUN amod
# y CCONJ cc
# conductas NOUN conj
# criminales ADJ amod
# que PRON nsubj
# pongan VERB acl
# en ADP case
# r NOUN obl
# iesgo VERB compound
# los DET det
#   SPACE dep
# derechos NOUN obj
# de ADP case
# ta PROPN nmod
# población NOUN nmod
# y CCONJ cc
# ta NUM det
# implementación NOUN conj
# del ADP case
# acuerdo NOUN nmod
# final ADJ amod
#   SPACE dep
# para ADP case
# la DET det
# terminación NOUN nmod
# del ADP case
# conflicto NOUN nmod
# y CCONJ cc
# la DET det
# construcción NOUN conj
# de ADP case
#   SPACE dep
# una DET det
# paz NOUN nmod
#   SPACE dep
# estable ADJ amod
# y CCONJ cc
# durader VERB conj
# a ADP mark
# define VERB ccomp
# que SCONJ mark
# las DET det
# alertas NOUN nsubj
# tempranas ADJ amod
#   SPACE dep
# son AUX cop
# e CCONJ cc
# t ADJ ccomp
# documento NOUN obj
# de ADP case
# advertencia NOUN nmod
# de ADP case
# carácter NOUN nmod
# preventivo ADJ amod
# emitido ADJ amod
# de ADP case
#   SPACE dep
# manera NOUN obl
# autónoma ADJ amod
#   SPACE dep
# por ADP case
# ta PROPN det
# defensoría PROPN obj
# del ADP case
#   SPACE dep
# pueblo NOUN nmod
# artículo PROPN obj
#   SPACE dep
# 6 NUM nummod
# en ADP case
# tos PROPN dep
# casos NOUN obl
#   SPACE dep
# que PRON nsubj
# ta PRON nmod
# entidad NOUN nsubj
#   SPACE dep
# evalúe VERB conj
#   SPACE dep
# que SCONJ mark
# tas PROPN iobj
# circunstanc PROPN flat
# ias PROPN iobj
# lo PRON obj
# ameriten VERB csubj
#   SPACE dep
# emitirá VERB ccomp
#   SPACE dep
# alertas ADJ obj
# tempranas ADJ amod
#   SPACE dep
# bajo ADP case
# el DET det
#   SPACE dep
# rótulo NOUN nmod
# de ADP case
# riesgo NOUN nmod
#   SPACE dep
# de ADP case
# inminencia NOUN nmod
#   SPACE dep
# artículo NOUN flat
# 15 NUM appos
# las DET det
# cuales PRON nsubj
# son AUX aux
# remitidas VERB acl
#   SPACE dep
# ta INTJ det
# secreta ADJ amod
# ría NOUN obl
# técnica ADJ amod
#   SPACE dep
# de ADP case
#   SPACE dep
# la DET det
# comisión NOUN nmod
# lntersectorial ADJ amod
#   SPACE dep
# para ADP case
# ta NOUN det
# respuesta NOUN obl
# rápida ADJ amod
# a ADP case
# las DET det
# alertas NOUN nmod
# tempranas ADJ amod
# ciprat NOUN nmod
# quien PRON nsubj
# una DET det
# vez NOUN obl
# recibida ADJ amod
# transmitirá VERB acl
# de ADP case
#   SPACE dep
# forma NOUN obl
#   SPACE dep
# inmediata ADJ amod
#   SPACE dep
# a ADP case
# las DET det
# entidades NOUN obj
#   SPACE dep
# nacionales ADJ amod
#   SPACE dep
# competentes ADJ amod
#   SPACE dep
# y CCONJ cc
# a ADP case
# tas PROPN nmod
# autoridades NOUN obj
#   SPACE dep
# territoriales ADJ amod
# para ADP case
# el DET det
# cumplimiento NOUN nmod
#   SPACE dep
# de ADP case
# sus DET det
# funciones NOUN nmod
#   SPACE dep
# y CCONJ cc
# la DET det
# adopción NOUN conj
# de ADP case
# las DET det
#   SPACE dep
# medidas NOUN nmod
# necesarias ADJ amod
# de ADP case
# reacción NOUN nmod
# rápida ADJ amod
# artículo NOUN appos
# 11 NUM nummod
#          SPACE dep
# carrera NOUN nmod
#   SPACE dep
# 9 NUM compound
#   SPACE dep
# 1621 NOUN appos
# bogotá ADJ amod
# dc PROPN appos
#   SPACE dep
# pbx PROPN flat
#   SPACE dep
# 57 NUM nummod
# 1 NUM appos
# 3147300 NUM appos
# línea NOUN appos
# nacional ADJ amod
# 01 NUM nummod
# 8000 NUM appos
# 914814 NUM nummod
#    SPACE dep
# www PROPN appos
# defensoria PROPN amod
# govco PROPN flat
#    SPACE dep
# plant VERB acl
# illa NOUN obj
# vigente ADJ advmod
#   SPACE dep
# desde ADP case
# 27062017 NUM nmod
#       SPACE dep
# rt NOUN compound
# v PRON compound
# t9 VERB appos
#   SPACE dep
# iso ADP advmod
# 9001 NUM nsubj
# 2008 NOUN nmod
#   SPACE dep
# ntc INTJ amod
# gp PROPN appos
# 10002009 NUM nummod
#    SPACE dep
# bureau NOUN nmod
#   SPACE dep
# veritas NOUN nmod
#    SPACE dep
# certific1tion VERB dep
#    SPACE dep
# 11coii NUM compound
# olllu VERB cop
#   SPACE dep
# in ADP case
# llllljiioll NOUN nsubj
# s PROPN appos
# ci PROPN flat
#      SPACE dep
# defensoría VERB flat
#   SPACE dep
# del ADP case
# pueblo NOUN nmod
#     SPACE dep
# col08 ADJ amod
# 1a NUM nummod
#     SPACE dep
# comunidades NOUN conj
# negras ADJ amod
# de ADP case
# la DET det
# cordillera NOUN nmod
# occidental ADJ amod
# copdiconc VERB amod
# aproximadamente ADV advmod
# 2650 NOUN nummod
#   SPACE dep
# personas NOUN nmod
# igualmente ADV advmod
# integrantes ADJ amod
# de ADP case
# las DET det
# juntas NOUN nmod
# de ADP case
# acción PROPN nmod
# comunal ADJ amod
# representantes NOUN appos
# de ADP case
#   SPACE dep
# organizaciones NOUN nmod
# como SCONJ mark
# el DET det
# movimiento NOUN nmod
# social ADJ amod
# y CCONJ cc
# político ADJ conj
# marcha VERB ccomp
# patriótica ADJ amod
# asociación PROPN obj
# de ADP case
#   SPACE dep
# trabajadores NOUN nmod
# campesinos ADJ amod
# de ADP case
# nariño NOUN nmod
#   SPACE dep
# astracan VERB obj
# dignidad NOUN obj
# campesina ADJ amod
# y CCONJ cc
# el DET det
# comité NOUN nsubj
# de ADP case
#   SPACE dep
# integración NOUN nmod
# del ADP case
# macizo NOUN nmod
# colombiano ADJ amod
#   SPACE dep
# cima NOUN compound
# personas NOUN appos
# en ADP case
# proceso NOUN nmod
# de ADP case
# reincorporación NOUN nmod
# e CCONJ cc
#   SPACE dep
# integrantes ADJ conj
# del ADP case
# partido NOUN nmod
# político ADJ amod
# fuerza PROPN appos
# alternativa ADJ amod
# revolucionaria ADJ amod
# del ADP case
# común ADJ amod
#   SPACE dep
# farc PROPN amod
# y CCONJ cc
#   SPACE dep
# autoridades NOUN conj
# municipales ADJ amod
# y CCONJ cc
# representantes NOUN conj
# de ADP case
# entidades NOUN nmod
# estatales ADJ amod
# que PRON nsubj
# se PRON expl:pv
# encuentlía VERB acl
# en ADP case
# el DET det
#   SPACE dep
# municipio NOUN obl
# de ADP case
# policarpa NOUN nmod
#      SPACE dep
# municipio NOUN appos
# de ADP case
# cumbitara ADV nmod
# se PRON expl:pv
# encuentran VERB advcl
# en ADP case
# situación NOUN obl
# de ADP case
# riesgo NOUN nmod
# aproxi ADJ amod
#   SPACE dep
# attamente ADJ advmod
# 4263 NUM nummod
#   SPACE dep
# personas NOUN obj
# de ADP case
# la DET det
# cabecera NOUN nmod
# municipal ADJ amod
# de ADP case
# cumbitara ADV nmod
# y CCONJ cc
# de ADP case
# sus DET det
# corregimientos NOUN conj
#   SPACE dep
# s·dón ADJ amod
# veredas NOUN nmod
#   SPACE dep
# sidón ADJ amod
# miguel PROPN appos
# nulpí PROPN flat
# san PROPN flat
# josé PROPN flat
# de ADP case
# taitán PROPN flat
# san PROPN flat
# martín PROPN flat
# el DET det
# desplayado NOUN appos
# ua ADJ amod
# a ADP case
# alito PROPN nmod
# nulpi DET flat
#   SPACE dep
# guadualito ADJ flat
#   SPACE dep
# pesquería VERB flat
# alto ADJ obj
# pesquería NOUN flat
# bajo ADP case
# el DET det
# placer NOUN nmod
# roncadora VERB amod
#   SPACE dep
# lalf NOUN nmod
#   SPACE dep
# ras VERB case
# la DET det
# florida PROPN nmod
# el DET det
#   SPACE dep
# pinde VERB nsubj
# la DET det
# espiga NOUN nsubj
# las DET det
# delicias NOUN nsubj
# monte NOUN advmod
# alto ADJ amod
# punta NOUN nmod
# de ADP case
# vargas PROPN nmod
# san PROPN flat
# agus PROPN flat
#   SPACE dep
# san PROPN appos
# josé PROPN flat
# del ADP case
# bijao PROPN flat
#   SPACE dep
# santa PROPN flat
# ana PROPN flat
# santa PROPN flat
# cecilia PROPN flat
# santa PROPN flat
# rosa PROPN flat
# vereda VERB flat
# santa PROPN flat
# rosa PROPN flat
# 11ia NUM nummod
# asco NOUN appos
# veredas NOUN amod
# damasco ADJ amod
#   SPACE dep
# guadualito ADJ obj
# y CCONJ cc
# buenos ADJ conj
#   SPACE dep
# aires PROPN amod
# dentro ADV advmod
# de ADP case
# estas DET det
# poblaciones NOUN obl
#   SPACE dep
# se PRON expl:pass
# elctientra VERB acl
# en ADP case
# riesgo NOUN obl
# integrantes ADJ advmod
#   SPACE dep
# de ADP case
# las DET det
# juntas NOUN nmod
# de ADP case
# acción PROPN nmod
# comunal ADJ amod
#   SPACE dep
# representantes NOUN obj
# de ADP case
# a ADP fixed
# · NOUN fixed
# z ADV fixed
# ciones NOUN nmod
# sociales ADJ amod
# como SCONJ mark
# el DET det
#   SPACE dep
# movimiento NOUN nmod
# social ADJ amod
# y CCONJ cc
# político ADJ conj
# marcha VERB ccomp
# patriótica ADJ amod
# asociación NOUN obj
# de ADP case
# trabajadores NOUN nmod
# campesinos ADJ amod
# de ADP case
# nariño NOUN nmod
#   SPACE dep
# astracan VERB obj
# dignidad NOUN obj
#   SPACE dep
# campesina ADJ obj
# y CCONJ cc
#   SPACE dep
# el DET det
# comité NOUN conj
#   SPACE dep
# ele PROPN flat
# lnte ADJ amod
# ación NOUN appos
#   SPACE dep
# del ADP case
# macizo NOUN nmod
# colombiano ADJ amod
#    SPACE dep
# cima NOUN appos
#   SPACE dep
# de ADP case
# igual ADJ fixed
# manera NOUN obl
#   SPACE dep
# se PRON expl:pass
# identifica VERB conj
#   SPACE dep
# vulnerabilidad NOUN obj
# a ADP case
#   SPACE dep
# e CCONJ cc
# sonas NOUN nmod
#   SPACE dep
# en ADP case
# proceso NOUN obl
#   SPACE dep
# de ADP case
# reincorporación NOUN nmod
#   SPACE dep
# e CCONJ cc
# integrantes ADJ conj
# del ADP case
# partido NOUN nmod
# político ADJ amod
# fuerza PROPN appos
# alterna ADJ amod
# · PROPN punct
# va VERB advcl
# revolucionaria ADJ obj
# del ADP case
# común ADJ amod
#   SPACE dep
# farc PROPN nmod
# y CCONJ cc
#   SPACE dep
# autoridades NOUN conj
# municipales ADJ amod
# y CCONJ cc
# representantes NOUN conj
# d NOUN cc
# eritidacles ADJ conj
# estatales ADJ amod
# que PRON nsubj
# se PRON expl:pv
# encuentran VERB acl
# en ADP case
# el DET det
#   SPACE dep
# municipio NOUN obl
# de ADP case
# cumbitara AUX nmod
#      SPACE dep
# municipio NOUN obj
# de ADP case
# magüi NOUN nmod
# payán ADJ amod
# se PRON expl:pv
# en ADP case
# ent PROPN obl
#   SPACE dep
# en ADP case
# situación NOUN obl
# de ADP case
# riesgo NOUN nmod
# aproximadamente ADV advmod
# 7000 NUM nummod
#   SPACE dep
# personas NOUN nsubj
# pertenecientes ADJ amod
# a ADP case
# la DET det
# asoia NOUN nmod
# ión NOUN nmod
# e CCONJ cc
# juntas ADJ conj
# asojuntas ADJ advcl
# veredas NOUN obj
#   SPACE dep
# lngualpí PROPN nsubj
# josé PROPN flat
#   SPACE dep
# lópez PROPN flat
# puibicito PROPN flat
# tortuga PROPN flat
# miguel PROPN flat
#   SPACE dep
# ortugb PROPN flat
# magaly PROPN flat
# el DET det
#   SPACE dep
# zorro NOUN flat
# bajo ADP case
# el DET det
#   SPACE dep
# zorro NOUN flat
# alto PROPN flat
# doradillo NOUN appos
# y CCONJ cc
# san PROPN conj
#   SPACE dep
# juan PROPN flat
# de ADP case
# dios PROPN flat
# consejo PROPN flat
#   SPACE dep
# comunitario ADJ flat
# manos NOUN flat
# amigas ADJ amod
# veredas ADJ amod
# canaibú ADJ amod
# punta NOUN obl
# de ADP case
# barco NOUN nmod
# san PROPN appos
#   SPACE dep
# luis PROPN flat
# trueno PROPN flat
# el DET det
# aguacate NOUN nsubj
# et PROPN flat
# carmelo PROPN flat
# pueblo PROPN flat
# nuevo ADJ amod
# juanchito ADJ amod
# angostura NOUN nsubj
# ricaurte ADJ amod
# canquisté PROPN amod
# nasalví VERB advcl
# las DET det
#   SPACE dep
# vilta ADJ amod
#   SPACE dep
# asalví VERB advcl
# la DET det
# unión NOUN obj
# nasalví PROPN advcl
# el DET det
# diviso NOUN nsubj
# cualalá VERB advcl
# el DET det
# chocho ADJ amod
# consejo NOUN obj
#   SPACE dep
# comunitario ADJ flat
# la DET det
# voz NOUN obj
#   SPACE dep
# él PRON appos
# s PROPN flat
# negros ADJ amod
# veredas PROPN appos
# guañambí PROPN flat
# alto PROPN amod
# estero NOUN appos
# bajo ADP case
# estero NOUN nmod
# el DET det
# naranjito NOUN nsubj
#    SPACE dep
# bella ADJ amod
# vista ADJ amod
# campo NOUN obj
# alegl VERB case
#   SPACE dep
# la DET det
# belleza NOUN obl
# el DET det
#   SPACE dep
# piande NOUN obl
#   SPACE dep
# el DET det
# cedrito PROPN nsubj
# el DET det
#   SPACE dep
# diviso NOUN advcl
# brisas NOUN obj
# de ADP case
#   SPACE dep
# hamburgo NOUN nmod
#   SPACE dep
# la DET det
# pampeta NOUN obj
# piragua NOUN nmod
# y CCONJ cc
# el DET det
# playón NOUN conj
# consejo NOUN compound
# comunitario ADJ amod
# la DET det
# amistad ADJ amod
# veredas NOUN nsubj
# narices PROPN appos
# y CCONJ cc
# la DET det
#   SPACE dep
# aurora NOUN conj
# y CCONJ cc
# el DET det
# consejo NOUN conj
# fomunitario ADJ amod
# unión PROPN appos
# patía NOUN appos
# viejo ADJ amod
# veredas NOUN nmod
# la DET det
# loma NOUN obj
# victoria ADJ amod
# brisas ADJ amod
# del ADP case
#   SPACE dep
# tabujo VERB nmod
# la DET det
# bella ADJ amod
# unión NOUN obj
# la DET det
# isla NOUN obj
# las DET det
# lajas NOUN nsubj
# bolívar ADJ appos
# la DET det
# rotura NOUN appos
# cascarrito ADJ amod
# y CCONJ cc
# rosario NOUN conj
# pertenecientes ADJ amod
# al ADP case
# municipio NOUN nmod
# de ADP case
# magüí NOUN nmod
# payán ADP case
#     SPACE dep
# municipio NOUN nmod
# de ADP case
# roberto NOUN nmod
# payán ADJ amod
# en ADP case
# este DET det
# municipio NOUN nmod
# se PRON expl:pv
# encuentran VERB advcl
# en ADP case
# riesgo NOUN obl
# aproximadamente ADV advmod
#   SPACE dep
# 6500 NUM nummod
# personas NOUN nsubj
#   SPACE dep
# pertenecientes ADJ amod
#   SPACE dep
# a ADP case
# los DET det
# consejos NOUN nmod
#   SPACE dep
# comunitarios ADJ amod
# agricultores ADJ amod
#   SPACE dep
# del ADP case
# patía NOUN nmod
#   SPACE dep
# el DET det
# progreso NOUN appos
#   SPACE dep
# veredas NOUN appos
#   SPACE dep
# chimbuza VERB advcl
#   SPACE dep
# limones NOUN amod
#   SPACE dep
# yalte NOUN obj
#   SPACE dep
# pumalde ADJ amod
#   SPACE dep
# remolinos NOUN nmod
#   SPACE dep
# maque NOUN flat
#   SPACE dep
# fátima NOUN amod
#   SPACE dep
# papí VERB amod
# la DET det
# playa NOUN obj
#   SPACE dep
# papí ADJ amod
#   SPACE dep
# la DET det
# unión NOUN obj
# papí ADJ amod
# las DET det
# palmas NOUN obj
# papí ADJ amod
# boca NOUN obj
# tamaje NOUN nmod
# pato NOUN obj
# y CCONJ cc
# el DET det
# cedro PROPN amod
# consejo NOUN conj
# comunitario ADJ amod
# integración NOUN obj
# del ADP case
# telembí ADJ amod
# veredas NOUN nmod
# lguambí PROPN amod
# santa PROPN amod
# helena PROPN flat
# loma ADJ flat
# linda ADJ flat
# la DET det
# mina NOUN obj
# laguna ADJ appos
# de ADP case
#   SPACE dep
# pirambí PROPN nmod
#   SPACE dep
# palo NOUN appos
# seco ADJ amod
#   SPACE dep
# gorgona PROPN appos
#   SPACE dep
# 1 NUM appos
# gorgona PROPN appos
# 11 NUM nummod
# guabal PROPN appos
#   SPACE dep
# el DET det
# diviso NOUN obj
#   SPACE dep
# chilví NOUN nmod
#   SPACE dep
# dorado ADJ amod
# bocas NOUN nmod
#   SPACE dep
# de ADP mark
# telembí ADJ advmod
#   SPACE dep
# palsapí VERB acl
# piscaundé ADJ amod
# consejo NOUN obj
# comunitario ADJ amod
# catanguero ADJ amod
# veredas NOUN obj
# pumbí ADJ amod
# las DET det
# lajas NOUN obj
# nerete PROPN amod
# guacuco PROPN appos
# panga NOUN obj
# laguna NOUN obj
# de ADP case
# pirí NOUN nmod
# y CCONJ cc
# playa NOUN conj
# el DET det
# medio NOUN nummod
#        SPACE dep
# carrera NOUN compound
#   SPACE dep
# 9 NUM compound
#   SPACE dep
# 1621 NOUN obl
# bogotá ADJ amod
# dc PROPN appos
#   SPACE dep
# pbx PROPN flat
#   SPACE dep
# 57 NUM nummod
# 1 NUM appos
# 3147300 NUM appos
# línea VERB appos
# nacional ADJ amod
#   SPACE dep
# 018000914814 NUM appos
#    SPACE dep
# wwwdefensoriagovco NOUN appos
#    SPACE dep
# plantilla NOUN conj
#   SPACE dep
# vigente ADJ amod
#   SPACE dep
# desde ADP case
#   SPACE dep
# 27062 NUM obl
# 017 NUM appos
#   SPACE dep
# iso ADP amod
# 90012008 NUM appos
#   SPACE dep
# ntc INTJ appos
# gp PROPN flat
# 1000 NUM nummod
# 2009 NUM appos
#     SPACE dep
# bureau NOUN appos
#   SPACE dep
# veritas NOUN appos
#    SPACE dep
# certific1tion NUM dep
#    SPACE dep
# lcollolloi VERB advcl
# ji PUNCT punct
# 6111111111 NUM nummod
#   SPACE dep
# g NUM obj
# 1 NUM nummod
#     SPACE dep
# defensoría VERB obj
#   SPACE dep
# del ADP case
# pueblo NOUN nmod
#      SPACE dep
# · NOUN punct
#    SPACE dep
# lljlloo NOUN flat
# cotr PROPN obj
#    SPACE dep
# ¡ PUNCT punct
# con ADP case
#   SPACE dep
# • NOUN dep
#   SPACE dep
# r DET fixed
#   SPACE dep
# 11uolto NUM obl
#   SPACE dep
# 1rcrn NUM appos
# w NUM appos
#   SPACE dep
# tryjflw VERB advcl
#    SPACE dep
# lfºkfclw NOUN obj
#    SPACE dep
# llllplellcaolcol VERB nsubj
# cll4 DET cop
#   SPACE dep
# ohrimfvfnlortl ADJ amod
# o CCONJ cc
# 101 NUM conj
#   SPACE dep
# lltlliu VERB amod
#    SPACE dep
# colomb PROPN flat
# ia PROPN dep
#                                                SPACE dep
# •wxiculltl NUM compound
# ollttjoot ADJ obj
# • NOUN flat
#   SPACE dep
# atwok•iufuj PROPN nsubj
# t VERB flat
# mi DET det
#      SPACE dep
# g NOUN dep
# escala NOUN flat
#    SPACE dep
# 132238 NUM nummod
# c• ADJ case
# lu PROPN obl
#      SPACE dep
# nooi ADJ flat
#    SPACE dep
# •to SPACE dep
# ° NUM punct
# cdjwt¡ag NOUN obj
#   SPACE dep
# « PUNCT punct
# t0rtclloiioii CCONJ flat
#   SPACE dep
# rtcm PROPN flat
#   SPACE dep
# uott PROPN amod
#        SPACE dep
# 1 NUM nummod
# antecedentes NOUN ROOT
#    SPACE dep
# sobre ADP case
# la DET det
# zona NOUN nmod
# de ADP case
# la DET det
# cordillera NOUN nmod
# occidental ADJ amod
# piedemonte ADV advmod
# costero ADJ amod
# frontera NOUN nmod
# y CCONJ cc
# costa NOUN conj
# pacífica ADJ amod
#   SPACE dep
# nariñense ADJ amod
# entre ADP case
# otras DET obj
#   SPACE dep
# subsisten VERB acl
# dinámicas NOUN nsubj
# de ADP case
# conflicto NOUN nmod
# armado ADJ amod
# interno ADJ amod
# pese NOUN mark
# a ADP fixed
# que SCONJ fixed
# se PRON expl:impers
# ha AUX aux
#   SPACE dep
# suscrito VERB advcl
# un DET det
#   SPACE dep
# acuerd0 NOUN nsubj
# final ADJ amod
#   SPACE dep
# que PRON nsubj
# puso VERB acl
# fin NOUN compound
#   SPACE dep
# a ADP case
# la DET det
# confrontación NOUN obj
# armada ADJ amod
# con ADP case
#   SPACE dep
# las DET det
# farc PROPN nmod
#   SPACE dep
# ep NOUN appos
# para ADP case
# · PROPN punct
# el DET det
#   SPACE dep
# caso NOUN nmod
# concreto ADJ amod
# la DET det
# cuenca NOUN obj
# del ADP case
# río NOUN nmod
# patía PROPN flat
# sobre ADP case
# el DET det
# territorio NOUN nmod
# de ADP case
# los DET det
# municipios NOUN nmod
# de ADP case
# policarpa NOUN nmod
#   SPACE dep
# cumbitara VERB advcl
# magüí NOUN obj
# payán ADJ amod
# y CCONJ cc
# roberto NOUN conj
# payán ADJ amod
# se PRON expl:pass
# constituye VERB advcl
# como SCONJ mark
# corredor NOUN obj
# estratégico ADJ amod
# sobre ADP case
# el DET det
#   SPACE dep
# cual PRON nsubj
# actúan VERB acl
# grupos NOUN nsubj
# armados ADJ amod
# ilegale VERB amod
# s NOUN obj
#     SPACE dep
# sobre ADP case
# la DET det
# cuenca NOUN nmod
# del ADP case
# río PROPN nmod
# patía PROPN amod
# actuaba VERB acl
# el DET det
# frente NOUN obj
# 29 NUM compound
# de ADP case
# las DET det
# farc PROPN nmod
#   SPACE dep
# ep VERB flat
# cuyos PRON nmod
# combatientes NOUN nsubj
# se PRON expl:pv
#   SPACE dep
# trasladaron VERB acl
# a ADP case
# la DET det
# zona NOUN obl
# veredal ADJ appos
# transitoria ADJ amod
# de ADP case
# normalización NOUN nmod
#   SPACE dep
# zvtn NOUN appos
# ubicada ADJ amod
# en ADP case
# la DET det
# finca NOUN obl
# la DET det
#   SPACE dep
# paloma NOUN nsubj
# vereda ADJ amod
# betania ADJ amod
# corregimiento NOUN appos
# madrigal ADJ flat
# municipio NOUN amod
# de ADP case
# policarpa NOUN nmod
# y CCONJ cc
#   SPACE dep
# luego ADV fixed
# del ADP det
# proceso NOUN conj
#   SPACE dep
# de ADP case
# dejación NOUN nmod
# de ADP case
# armas NOUN nmod
# continuaron VERB conj
# su DET det
# proceso NOUN obj
# de ADP case
#   SPACE dep
# reincorporación NOUN nmod
#   SPACE dep
# política ADJ amod
# económica ADJ amod
# y CCONJ cc
# social ADJ conj
#   SPACE dep
# en ADP case
# el DET det
# espacio NOUN nmod
# territorial ADJ amod
# de ADP case
# capacitación NOUN nmod
# y CCONJ cc
#   SPACE dep
# reincorporación NOUN conj
#   SPACE dep
# etcr NOUN nmod
# reubicado ADJ amod
# en ADP case
# el DET det
# estrecho NOUN obl
#            SPACE dep
# carrera NOUN nmod
#   SPACE dep
# 9 NUM nummod
#   SPACE dep
# 1621 NOUN obl
# bogotá ADJ amod
# dc PROPN appos
#   SPACE dep
# pbx PROPN flat
#   SPACE dep
# 57 NUM nummod
# 1 NUM appos
# 3147300 NUM obl
# línea VERB obj
# nacional ADJ amod
#   SPACE dep
# 01 NUM appos
# 8000 NUM nmod
# 914814 NUM appos
#    SPACE dep
# wwwdefensoriagovco NOUN obj
#    SPACE dep
# plantilla NOUN nmod
# vigente ADJ amod
# desde ADP case
# 27062017 NUM nummod
#         SPACE dep
# iso NOUN compound
# 9001 NUM appos
# 2008 NOUN appos
#   SPACE dep
# ntc INTJ compound
# gp PROPN appos
# 10002009 NUM nummod
#   SPACE dep
# buiieau VERB obj
#   SPACE dep
# veritas NOUN nmod
#    SPACE dep
# c1rtific ADP nsubj
# 1tion NUM appos
#    SPACE dep
# r NOUN conj
#   SPACE dep
# ct11011ns VERB dep
# 1•••1md11s NUM dep
#       SPACE dep
# defensoria ADJ amod
#    SPACE dep
# del ADP case
# pueblo NOUN nmod
#     SPACE dep
# colom81a VERB dep
#     SPACE dep
# municipio NOUN amod
# de ADP case
# el DET det
# bordo NOUN nmod
# departamento NOUN nmod
# de ADP case
# cauca NOUN nmod
# junto ADJ case
# con ADP fixed
# exintegrantes NOUN obl
# del ADP case
# frente NOUN nmod
# 8 NUM compound
# ° NUM nummod
# de ADP case
# las DET det
#   SPACE dep
# mismas DET det
# farc NOUN nmod
#   SPACE dep
# ep NOUN appos
#     SPACE dep
# los DET det
# espacios NOUN nsubj
# dejados ADJ amod
# por ADP case
# las DET det
# farc PROPN obj
#   SPACE dep
# ep NOUN appos
# en ADP case
# la DET det
# cuenca NOUN obl
# del ADP case
# río NOUN nmod
# patía PROPN flat
# han AUX aux
# sido AUX aux
# ocupados VERB csubj
# por ADP case
#   SPACE dep
# grupos NOUN obj
#   SPACE dep
# armados ADJ amod
#   SPACE dep
# ilegales ADJ advmod
# transformando VERB advcl
# la DET det
# dinámica NOUN obj
# del ADP case
# conflicto NOUN nmod
#   SPACE dep
# han AUX aux
# surgido VERB conj
# nuevos ADJ amod
# grupos NOUN nsubj
#   SPACE dep
# armados ADJ amod
#   SPACE dep
# ilegales ADJ advmod
#   SPACE dep
# como SCONJ mark
# resistencia NOUN nmod
# campesina ADJ amod
#   SPACE dep
# los DET det
# del ADP case
# vaca NOUN nmod
# los DET det
#   SPACE dep
# de ADP case
# sábalo NOUN dep
#   SPACE dep
# guerrillas NOUN appos
#   SPACE dep
# unidas ADJ flat
# del ADP case
# pacifico PROPN nmod
# compuestos ADJ amod
# por ADP case
# exintegrantes NOUN nmod
# de ADP case
# las DET det
# farc PROPN nmod
#   SPACE dep
# ep NOUN appos
# que PRON nsubj
# no ADV advmod
# s VERB acl
# aaogieron VERB advcl
# a ADP case
#   SPACE dep
# procesos NOUN obj
# de ADP case
# desmovilización NOUN nmod
# o CCONJ cc
# de ADP case
# reincorporación NOUN conj
#   SPACE dep
# a ADP case
# la DET det
# vida NOUN nmod
# civil ADJ amod
# o CCONJ cc
# por ADP mark
# quienes PRON nsubj
# se PRON expl:pv
# acogie ADJ nsubj
# on ADJ nsubj
# a ADP case
#   SPACE dep
# este NOUN obl
# y CCONJ cc
# no ADV advmod
# continuaron VERB conj
# y CCONJ cc
# que SCONJ mark
# podrían AUX aux
#   SPACE dep
# entrar VERB conj
# en ADP case
#   SPACE dep
# disputa NOUN obl
#   SPACE dep
# entre ADP case
# sí PRON nmod
# o CCONJ cc
#   SPACE dep
# generar VERB conj
# alianzas NOUN obj
# a ADP mark
#   SPACE dep
# ando VERB advcl
#   SPACE dep
# derechos NOUN obj
#   SPACE dep
# fundamentales ADJ amod
#   SPACE dep
# de ADP case
# la DET det
# población NOUN nmod
# civil ADJ amod
#   SPACE dep
# el DET det
# eln PROPN obj
# y CCONJ cc
# las DET det
# autodefens ADJ conj
#   SPACE dep
# rtanistas VERB obj
#   SPACE dep
# de ADP case
#   SPACE dep
# colombia PROPN nmod
# agc VERB nsubj
#   SPACE dep
# aprovechando VERB xcomp
# los DET det
# espacios NOUN obj
#   SPACE dep
# dejados ADJ amod
#   SPACE dep
# por ADP case
# las DET det
# farc PROPN obj
#    SPACE dep
# ep PROPN appos
# arn1a PROPN appos
# an PROPN flat
# on PROPN flat
# generar VERB xcomp
#   SPACE dep
# disputas NOUN obj
# por ADP case
# el DET det
# control NOUN obj
# poblacional ADJ amod
#   SPACE dep
# territorial ADJ amod
# y CCONJ cc
# de ADP case
# economías NOUN conj
# ilegale ADJ amod
#   SPACE dep
# para ADP mark
# ratificar VERB acl
# su DET det
#   SPACE dep
# presencia NOUN obj
# en ADP case
# las DET det
# zonas NOUN nmod
# e CCONJ cc
# incluso ADV conj
# para ADP mark
# expandirse VERB acl
# para ADP mark
# tener VERB advcl
# un DET det
# do ADP det
#   SPACE dep
# iaio NOUN obj
# egemónico ADJ amod
# de ADP case
# las DET det
#   SPACE dep
# actividades NOUN nmod
#   SPACE dep
# ilícitas ADJ amod
#   SPACE dep
# de ADP case
# narcotráfico NOUN nmod
# y CCONJ cc
# minería NOUN conj
# que PRON nsubj
# existen VERB acl
# a ADP case
# lo PRON fixed
# larrgo NOUN fixed
#   SPACE dep
# y CCONJ cc
# n NOUN conj
# ho PROPN flat
# del ADP case
#   SPACE dep
# corredor NOUN obl
#   SPACE dep
# del ADP case
#   SPACE dep
# río PROPN nmod
# patía VERB appos
#   SPACE dep
# y CCONJ cc
# que SCONJ mark
# podría AUX aux
# generar VERB conj
# afectaciones NOUN obj
# directas ADJ amod
# e CCONJ cc
# indirectas ADJ conj
# e CCONJ cc
#   SPACE dep
# materia NOUN conj
# de ADP case
# derechos NOUN nmod
#   SPACE dep
# humanos NOUN compound
# y CCONJ cc
# derecho NOUN conj
# internacional ADJ amod
# humanitario ADJ amod
#      SPACE dep
# en ADP case
# los DET det
# últimos ADJ amod
#   SPACE dep
# tres NUM nummod
# meses NOUN nmod
#   SPACE dep
# a ADP case
# lo PRON fixed
# largo NOUN fixed
# de ADP fixed
# la DET det
# ribera NOUN nmod
# del ADP case
# río NOUN nmod
# pt PROPN amod
#   SPACE dep
# viene VERB advcl
# presentado ADJ obj
# acciones NOUN obj
#   SPACE dep
# armadas ADJ amod
# que PRON nsubj
# han AUX aux
# dejado VERB acl
# como SCONJ advmod
# consecuencia NOUN obj
# a ADP case
#   SPACE dep
# aza PROPN obj
#   SPACE dep
# asesinatos NOUN obj
# selectivos ADJ amod
# y CCONJ cc
# de ADP case
#   SPACE dep
# configuración NOUN conj
# múltiple ADJ amod
# desplazamientos NOUN obj
#   SPACE dep
# individu ADJ obj
# éle NUM obl
#   SPACE dep
# flesplazamientos NOUN obj
#   SPACE dep
# masivos ADJ amod
# restricciones NOUN obj
#   SPACE dep
# a ADP case
# la DET det
# movilidad NOUN nmod
# desaparición NOUN amod
# forzada ADJ amod
# confinami ADJ obj
# ritos NOUN obj
#   SPACE dep
# y CCONJ cc
# enfrentamientos NOUN conj
# en ADP case
# medio NOUN fixed
# de ADP fixed
# la DET det
#   SPACE dep
# población NOUN nmod
# civil ADJ amod
#   SPACE dep
# que PRON nsubj
# han AUX aux
# afectado VERB acl
# la DET det
# vida NOUN obj
# e CCONJ cc
# int PROPN conj
# gridad NOUN flat
# e CCONJ cc
# la DET det
# población NOUN conj
# civil ADJ amod
#   SPACE dep
# líderes NOUN obj
#   SPACE dep
# y CCONJ cc
# lideresas NOUN conj
#   SPACE dep
# socials PROPN amod
#   SPACE dep
# comunales ADJ amod
# y CCONJ cc
# defensores NOUN conj
# de ADP case
#   SPACE dep
# dereoho NOUN nmod
# u CCONJ cc
#   SPACE dep
# anos NOUN conj
#      SPACE dep
# dentro ADV advmod
#   SPACE dep
# de ADP case
# los DET det
# casos NOUN obl
# más ADV advmod
# sobresalient ADJ amod
#   SPACE dep
# s NOUN appos
# uentran VERB acl
# los DET det
# siguientes ADJ amod
#      SPACE dep
# el DET det
# pasado ADJ amod
# 27 NUM obl
# de ADP case
# noviembre NOUN compound
# de ADP case
#   SPACE dep
# 201 NUM compound
# e CCONJ cc
# la DET det
# vereda NOUN conj
#   SPACE dep
# pueblo NOUN appos
# nuevo ADJ amod
# del ADP case
# municipio NOUN nmod
# de ADP case
# magüí NOUN nmod
#   SPACE dep
# payán ADJ amod
#    SPACE dep
# pierden VERB advcl
# la DET det
# vida NOUN obj
# trece NUM nummod
# 13 NUM nummod
#   SPACE dep
# perso NOUN obj
#   SPACE dep
# as NOUN det
# en ADP case
# medio NOUN fixed
# de ADP fixed
# enfrentamientos NOUN nmod
# entre ADP case
#   SPACE dep
# el DET det
# eln PROPN nmod
#   SPACE dep
# y CCONJ cc
# disidencias NOUN conj
#   SPACE dep
# de ADP case
# las DET det
# farce NOUN nmod
# p PROPN amod
# y CCONJ cc
# en ADP case
# el DET det
# que PRON obl
# e CCONJ cc
# sesin NOUN conj
# do ADP case
# dinson PROPN nmod
# ortiz PROPN flat
#   SPACE dep
# bolaños NOUN conj
# quien PRON nsubj
#   SPACE dep
# fungía VERB advcl
#   SPACE dep
# como SCONJ mark
# representante NOUN obj
#   SPACE dep
# legal ADJ amod
# del ADP case
# consejo PROPN nmod
# 0mumi NUM nummod
# ario ADJ amod
# manos NOUN appos
# amigas ADJ amod
# del ADP case
# patía NOUN nmod
# grande ADJ amod
# y CCONJ cc
# yensi PROPN nsubj
# carolina PROPN flat
# orobio ADJ flat
#   SPACE dep
# arboleda PROPN flat
# mujer NOUN flat
#   SPACE dep
# civil PROPN flat
# uien PROPN flat
# s PROPN flat
#   SPACE dep
# encontraba VERB conj
#   SPACE dep
# en ADP case
# su DET det
# tercer ADJ amod
#   SPACE dep
# mes NOUN obl
# de ADP case
# gestación NOUN nmod
#      SPACE dep
# posterior ADJ amod
#   SPACE dep
# a ADP case
# ello PRON nmod
# en ADP case
# el DET det
# municipio NOUN nmod
# de ADP case
# roberto PROPN nmod
# payán ADP flat
# el DET det
# día NOUN obl
# 28 NUM compound
# de ADP case
# noviembre NOUN compound
# de ADP case
# 2017 NUM compound
# ocurren VERB advcl
#   SPACE dep
# dos NUM nummod
# acciones NOUN nsubj
# jlt1e PROPN nmod
#   SPACE dep
# evié1encian VERB advcl
# el DET det
# deterioro NOUN nsubj
# de ADP case
# la DET det
# situación NOUN nmod
#   SPACE dep
# humanitaria ADJ amod
#   SPACE dep
# cuando SCONJ mark
#   SPACE dep
# tres NUM nummod
# mujeres NOUN dep
#   SPACE dep
# fueron AUX cop
# amenazac1as ADJ advmod
# ae DET dep
# muerte NOUN advcl
# por ADP case
# integrantes NOUN nmod
# de ADP case
# grupos NOUN nmod
#   SPACE dep
# armados ADJ amod
#   SPACE dep
# ilegales ADJ advmod
# y CCONJ cc
#   SPACE dep
# que SCONJ nsubj
# por ADP case
# lina NOUN obl
#   SPACE dep
# oport NOUN flat
# □ PUNCT punct
# a ADP case
# intervención NOUN nmod
# institucional ADJ amod
# lograron VERB conj
# ser AUX aux
# evacuadas VERB xcomp
# de ADP case
# la DET det
# zona NOUN obj
#   SPACE dep
# ese DET det
# mismo DET det
# día NOUN obl
# se PRON expl:pass
#   SPACE dep
# reporta VERB advcl
# l ADJ dep
# 9esaparición NUM nummod
# forzada ADJ amod
# de ADP case
# tres NUM nummod
# personas NOUN nmod
# identificadas ADJ amod
# como SCONJ mark
# alberto PROPN obj
#   SPACE dep
# meza PROPN flat
# diego PROPN flat
# meza PROPN flat
#    SPACE dep
# y CCONJ cc
# ra DET det
#   SPACE dep
# l PROPN conj
# gastillo PROPN flat
# quienes PRON nsubj
# fueron AUX aux
# interceptados VERB acl
# por ADP case
# presuntos ADJ amod
# integrantes NOUN obj
# del ADP case
# grupo NOUN nmod
# armado ADJ amod
#   SPACE dep
# ilegal ADJ obj
# denominado ADJ amod
# guerrillas NOUN obj
# unidas ADJ amod
# del ADP case
# pacífico PROPN nmod
# en ADP case
# el DET det
# punto NOUN obl
# conocido ADJ amod
# como SCONJ mark
# bocas NOUN obl
# del ADP case
#   SPACE dep
# telembí ADJ amod
# familiares NOUN nmod
# de ADP case
# las DET det
#   SPACE dep
# personas NOUN nmod
# desaparecidas ADJ amod
#   SPACE dep
# temen VERB advcl
#   SPACE dep
# que SCONJ mark
# hayan AUX aux
# sido AUX aux
# asesinadas VERB ccomp
#      SPACE dep
# por ADP case
# otra DET det
# parte NOUN obl
# el DET det
# asesinato NOUN nsubj
# del ADP case
# comunero NOUN nmod
# jorison PROPN appos
# riascos ADJ amod
# en ADP case
# la DET det
# vereda NOUN nmod
# santa ADJ amod
# rosa PROPN flat
# del ADP case
#   SPACE dep
# municipio NOUN nmod
# de ADP case
# policarpa NOUN nmod
# y CCONJ cc
# de ADP case
# roberth PROPN conj
# alexander PROPN appos
# quiñones PROPN obj
# muerto ADJ amod
# en ADP case
# el DET det
# casco NOUN obl
# urbano ADJ amod
# del ADP case
#   SPACE dep
# municipio NOUN nmod
#   SPACE dep
# de ADP case
# magüí NOUN nmod
#   SPACE dep
# payán ADJ amod
#   SPACE dep
# cuya PRON nmod
# autoría NOUN obl
# al ADP case
# parecer VERB advcl
#   SPACE dep
# corresponde VERB xcomp
#   SPACE dep
# a ADP case
# integrantes ADJ obj
#   SPACE dep
# del ADP case
# eln PROPN nmod
#          SPACE dep
# carrera NOUN obj
#   SPACE dep
# 9 NUM compound
#   SPACE dep
# 1621 NOUN obl
# bogotá ADJ amod
# dc PROPN appos
#   SPACE dep
# pbx PROPN flat
# 57 NUM appos
# 1 NUM appos
# 3147300 NUM appos
# línea NOUN appos
# nacional ADJ amod
# 01 NUM nummod
# 8000 NUM appos
# 914814 NUM nummod
#    SPACE dep
# www PROPN appos
# defensoriagovco ADJ amod
#    SPACE dep
# plantilla NOUN appos
# vigente ADJ amod
# desde ADP case
# 27062017 NUM obl
#    SPACE dep
# iso NOUN compound
# 90012008 NUM nummod
#   SPACE dep
# ntc INTJ obj
# gp PROPN flat
# 1000 NUM appos
# 2009 NUM obl
#    SPACE dep
# bureau NOUN obj
#   SPACE dep
# yerita PROPN amod
# s PROPN appos
#    SPACE dep
# cort ADJ fixed
# icltion PROPN amod
#     SPACE dep
# rc01ull3ql ADJ amod
# fr NOUN dep
#   SPACE dep
# 611mril NUM obj
# u CCONJ cc
# et PROPN conj
#      SPACE dep
# defensoría VERB flat
#   SPACE dep
# del ADP case
# pueblo NOUN nmod
#    SPACE dep
# colomb PROPN amod
# ia PROPN appos
#      SPACE dep
# manera NOUN dep
# en ADP case
# el DET det
# municipio NOUN obl
# de ADP case
# policarpa NOUN nmod
# en ADP case
# el DET det
# corregimiento NOUN nmod
# de ADP case
# sánchez PROPN nmod
# se PRON expl:pass
# pueden AUX aux
# presentar VERB nsubj
#   SPACE dep
# alianzas NOUN nsubj
#   SPACE dep
# entre ADP case
# grupos NOUN nmod
#   SPACE dep
# armados ADJ amod
#   SPACE dep
# ilegales ADJ amod
#   SPACE dep
# como SCONJ mark
#   SPACE dep
# es AUX cop
# el DET det
# caso NOUN obl
# del ADP case
# grupo NOUN nmod
#   SPACE dep
# disidente NOUN amod
# conocido ADJ amod
# como SCONJ mark
#   SPACE dep
# los DET det
#   SPACE dep
# del ADP case
# vaca NOUN obl
#   SPACE dep
# con ADP case
# las DET det
# autodefensas NOUN nmod
#   SPACE dep
# gaitanistas ADJ nsubj
#   SPACE dep
# de ADP case
# colombia PROPN obj
# agc PROPN flat
# de ADP mark
#   SPACE dep
# efectuarse VERB advcl
# podría AUX aux
# generarse VERB xcomp
#   SPACE dep
# una DET det
# confrontación NOUN obj
# en ADP case
# medio NOUN fixed
#   SPACE dep
# de ADP fixed
# la DET det
#   SPACE dep
# población NOUN nmod
# civil ADJ amod
#   SPACE dep
# con ADP case
# el DET det
# grupo NOUN nmod
# disidente ADJ amod
# conocido ADJ amod
# como SCONJ mark
# los DET det
# de ADP case
#   SPACE dep
# sábalo NOUN obl
#   SPACE dep
# quienes PRON nsubj
#   SPACE dep
# también ADV advmod
# tienen VERB advcl
# presencia NOUN obj
# en ADP case
# este DET det
# punto NOUN obl
# y CCONJ cc
# dominan VERB conj
# parte NOUN obj
# de ADP case
# las DET det
# actividades NOUN obj
#   SPACE dep
# de ADP case
# economía NOUN nmod
# ilícita ADJ amod
# de ADP case
# la DET det
# zona NOUN nmod
#   SPACE dep
# también ADV advmod
#   SPACE dep
# podrían AUX aux
#   SPACE dep
# ocurrir VERB advcl
#   SPACE dep
# homicidios NOUN obj
#   SPACE dep
# selectivos ADJ amod
#   SPACE dep
# desplazamientos NOUN obj
# forzados ADJ amod
#   SPACE dep
# desapariciones NOUN nmod
# forzadas ADJ amod
# amenazas NOUN obj
# • NOUN punct
#     SPACE dep
# en ADP case
# el DET det
# municipio NOUN nmod
#   SPACE dep
# de ADP case
# cumbitara VERB acl
# la DET det
# llegada NOUN appos
# de ADP case
# las DET det
# agc PROPN nmod
# además ADV advmod
#   SPACE dep
# de ADP mark
# fortalecer VERB acl
#   SPACE dep
# una DET det
# eveqtuat NOUN obj
#   SPACE dep
# alíanza NOUN amod
#   SPACE dep
# con ADP case
# el DET det
# grupo NOUN nmod
# de ADP case
# el DET det
# vaca PROPN nmod
# significa VERB advcl
# la DET det
# toma NOUN obj
# de ADP case
# casi ADV advmod
# la DET det
# totalidad NOUN nmod
# de ADP case
# la DET det
# cord PROPN nmod
# · PROPN flat
# naoocidental PROPN amod
#   SPACE dep
# nariñense ADJ amod
# teniendo VERB advcl
# en ADP case
# cuenta NOUN compound
# que SCONJ mark
# esta DET det
# agrupación NOUN nsubj
# hace VERB ccomp
# fuerte ADJ obj
#   SPACE dep
# presenaia ADJ obj
# n NOUN obj
# lo PRON det
# municipios NOUN obj
#   SPACE dep
# de ADP case
# leiva PROPN nmod
# y CCONJ cc
# el DET det
# rosario NOUN conj
# por ADP case
#   SPACE dep
# consiguiente ADJ fixed
# se PRON expl:pass
#   SPACE dep
# estima VERB advcl
#   SPACE dep
# confrontaciones NOUN nsubj
#   SPACE dep
# con ADP case
# l PROPN nmod
# eln PROPN flat
#   SPACE dep
# a ADP case
# rupación NOUN nmod
#   SPACE dep
# que PRON nsubj
#   SPACE dep
# ha AUX aux
# tenido VERB acl
# presencia NOUN obj
# sostenida ADJ amod
# en ADP case
# la DET det
# zona NOUN obl
#   SPACE dep
# y CCONJ cc
# de ADP mark
# quienes PRON obj
#   SPACE dep
# a ADP advmod
# pesar NOUN fixed
#   SPACE dep
# del• ADV fixed
# e CCONJ cc
# bilateral ADJ conj
#   SPACE dep
# pactado ADJ conj
# con ADP case
#   SPACE dep
# el DET det
# gobierno PROPN obj
# nacional ADJ amod
# se PRON expl:pv
# encuentra VERB advcl
# en ADP case
# proceso NOUN obl
# de ADP case
# expanción NOUN nmod
# territ0 ADJ amod
#   SPACE dep
# 1al NUM nsubj
# especialmente ADV advmod
# en ADP case
# las DET det
#   SPACE dep
# veredas NOUN nmod
# sidón ADJ amod
# miguel PROPN appos
# nulpí PROPN flat
# san PROPN flat
# josé PROPN flat
# de ADP case
# taitán PROPN flat
# san PROPN flat
# martí PROPN flat
#   SPACE dep
# e CCONJ cc
# d NOUN conj
# s NOUN flat
# layado ADJ amod
# guayabalito ADJ case
#   SPACE dep
# pesquería NOUN nmod
# alto ADJ amod
# pesquería NOUN nmod
# bajo ADP case
# monte NOUN nmod
# alto ADJ amod
# delicia NOUN appos
#    SPACE dep
# esier ADJ flat
# to PROPN appos
# esperanza NOUN flat
# pisanda ADJ flat
#   SPACE dep
# herradura NOUN flat
#   SPACE dep
# llanoverde VERB flat
#   SPACE dep
# tabiles ADJ flat
#   SPACE dep
# san PROPN flat
# antonio PROPN flat
#   SPACE dep
# bellavista ADJ flat
#   SPACE dep
# veintig PROPN flat
#   SPACE dep
# atro ADJ flat
# santa PROPN flat
# martha PROPN flat
#   SPACE dep
# santa ADJ flat
#   SPACE dep
# rosa PROPN flat
#   SPACE dep
# cristo NOUN flat
# rey PROPN flat
# el DET det
# balso NOUN nsubj
# y CCONJ cc
#   SPACE dep
# yanazara PROPN conj
#      SPACE dep
# en ADP case
# magüí NOUN nmod
# payán ADJ amod
# hay AUX advcl
# presencia NOUN obj
# del ADP case
# eln PROPN nmod
# y CCONJ cc
# del ADP case
# g NOUN conj
# o CCONJ cc
# ar PROPN conj
# ado PROPN flat
# resistencia PROPN flat
# campesina ADJ amod
# con ADP case
#   SPACE dep
# incidencia NOUN nmod
# en ADP case
# las DET det
# veredas NOUN nmod
#   SPACE dep
# de ADP case
# asojuntas NOUN nmod
#   SPACE dep
# y CCONJ cc
# los DET det
# corisejos NOUN amod
#   SPACE dep
# comunitarios ADJ conj
#   SPACE dep
# manos NOUN obj
#   SPACE dep
# amigas NOUN amod
#   SPACE dep
# la DET det
# voz NOUN obj
#   SPACE dep
# de ADP case
# los DET det
# negros NOUN nmod
#   SPACE dep
# la DET det
# amistad NOUN appos
# y CCONJ cc
# unión PROPN conj
# patía PROPN flat
# viej0 PROPN appos
#   SPACE dep
# stos DET det
# grupos NOUN appos
# armados ADJ amod
# ilegales ADJ amod
# se PRON expl:pv
# enfrentaron VERB advcl
#   SPACE dep
# el DET det
# 27 NUM obl
# de ADP case
# noviembre NOUN compound
# de ADP case
# 2017 NUM compound
# pudiéndose VERB advmod
# p NOUN compound
# es AUX cop
#   SPACE dep
# n NOUN nsubj
# ar NOUN flat
# uevos PROPN amod
#   SPACE dep
# combates NOUN appos
# los DET det
#   SPACE dep
# cuales PRON nsubj
# podrían AUX aux
#   SPACE dep
# ocurrir VERB csubj
#   SPACE dep
# en ADP case
# medio NOUN fixed
# de ADP fixed
# la DET det
# población NOUN obl
# civil ADJ amod
#   SPACE dep
# esta DET det
# zljsma NOUN obj
# situación NOUN nsubj
# podría AUX aux
# presentarse VERB xcomp
# en ADP case
# el DET det
# municipio NOUN obl
# de ADP case
#   SPACE dep
# roberto NOUN nmod
# payán ADJ amod
# ya ADV mark
# que SCONJ fixed
# en ADP case
# su DET det
# terri NOUN obl
# 0ti0 NUM nummod
# hage VERB advcl
# presencia NOUN obj
# el DET det
# eln PROPN obj
# resistencia NOUN flat
# campesina ADJ amod
# y CCONJ cc
#   SPACE dep
# guerrillas NOUN conj
# unidas ADJ amod
# del ADP case
# pacífico PROPN nmod
# yza PROPN flat
#   SPACE dep
# con ADP mark
# incursionar VERB advcl
#   SPACE dep
# las DET det
# agc PROPN obj
#      SPACE dep
# las DET det
# estructuras NOUN appos
# ilegales ADJ amod
#   SPACE dep
# estári VERB nsubj
#   SPACE dep
# intim1 ADJ xcomp
#   SPACE dep
# ando VERB advcl
# a ADP case
# la DET det
# población NOUN obj
# en ADP advmod
# general NOUN fixed
#   SPACE dep
# y CCONJ cc
# a ADP case
# funcionarios NOUN conj
# públicos ADJ amod
#   SPACE dep
# encargados ADJ amod
# de ADP mark
# atender VERB xcomp
# a ADP case
# l PROPN obj
# s NOUN flat
# víct1mas ADJ obj
# para ADP mark
# que SCONJ mark
# no ADV advmod
# realicen VERB advcl
# sus DET det
# funciones NOUN obj
# de ADP case
# atención NOUN nmod
#   SPACE dep
# asistencia NOUN obj
# y CCONJ cc
# reparac PROPN conj
# · PROPN flat
# ón DET dep
# 4nteg NUM appos
# al ADP case
#   SPACE dep
# invisibilizando VERB advcl
# el DET det
# impacto NOUN obj
# de ADP case
# la DET det
# acción NOUN nmod
# violenta ADJ amod
# en ADP case
# los DET det
#   SPACE dep
# territorios NOUN nmod
# algunas DET det
# alcalaías NOUN obj
# municipales ADJ amod
# e CCONJ cc
# instituciones NOUN conj
# como SCONJ mark
# el DET det
# icbf NOUN advcl
# han AUX aux
# suspendido VERB conj
#   SPACE dep
# temporalmente ADV advmod
# el DET det
# ingreso NOUN obj
# de ADP case
# personal NOUN nmod
#   SPACE dep
# a ADP case
# zona NOUN nmod
#   SPACE dep
# rural ADJ amod
# de ADP case
# estos DET det
#   SPACE dep
# municipios NOUN nmod
# magüí ADJ amod
#   SPACE dep
# payán ADJ amod
# y CCONJ cc
# roberto NOUN conj
#   SPACE dep
# payán ADP amod
#   SPACE dep
# debido ADJ case
# a ADP fixed
# 1las NUM nummod
# suficientes ADJ amod
# garantías NOUN obl
# de ADP case
# seguridad NOUN nmod
# para ADP case
# su DET det
# acceso NOUN nmod
# y CCONJ cc
# permanencia NOUN conj
# en ADP case
# las DET det
#   SPACE dep
# zonas NOUN nmod
# donde PRON obl
# rindan VERB acl
# la DET det
# atención NOUN obj
# a ADP case
# población NOUN nmod
# vulnerable ADJ amod
#      SPACE dep
# por ADP case
# lo PRON det
# anterior ADJ advmod
# desde ADP case
# el DET det
# sistema NOUN nmod
# de ADP case
# alertas NOUN nmod
#   SPACE dep
# tempranas ADJ flat
# advertimos VERB advcl
# ante ADP case
# la DET det
# inminencia NOUN obl
# de ADP case
#   SPACE dep
# violacion NOUN nmod
#   SPACE dep
# masivas ADJ amod
#   SPACE dep
# a ADP case
# los DET det
# derechos NOUN obj
#   SPACE dep
# humanos NOUN amod
#   SPACE dep
# e CCONJ cc
# infracciones NOUN conj
#   SPACE dep
# al ADP case
# dih NOUN nmod
#   SPACE dep
# como SCONJ mark
#   SPACE dep
# amenazas NOUN nmod
# asesinatos ADJ amod
#   SPACE dep
# selectivos ADJ amod
# desplazamientos NOUN nmod
# individuales ADJ amod
# reclutamientos NOUN nmod
# forzados ADJ amod
# y CCONJ cc
# utilización NOUN conj
# ilícita ADJ amod
# de ADP case
#   SPACE dep
# niños PROPN nmod
# niñas PROPN flat
# y CCONJ cc
# adolescentes ADJ conj
# desplazamientos NOUN nmod
# masivos ADJ amod
# restricciones NOUN nmod
# a ADP case
# la DET det
# movilidad NOUN nmod
#   SPACE dep
# desaparición NOUN amod
# forzada ADJ amod
# confinamientos NOUN obj
# combates ADJ amod
# con ADP case
# interposición NOUN nmod
# de ADP case
# la DET det
# población NOUN nmod
# civil ADJ amod
#   SPACE dep
# ataques NOUN nmod
# indiscriminados ADJ amod
# entre ADP case
# otras PRON nmod
#             SPACE dep
# carrera NOUN nmod
#   SPACE dep
# 9 NUM appos
#   SPACE dep
# 1621 NOUN appos
# bogotá ADJ amod
# dc PROPN appos
#   SPACE dep
# pbx PROPN flat
#   SPACE dep
# 57 NUM nummod
# 1 NUM appos
# 3147300 NUM nmod
# línea VERB obj
# nacional ADJ amod
#   SPACE dep
# 01 NUM appos
# 8000 NUM nmod
# 914814 NUM appos
#    SPACE dep
# wwwdefensoriagovco NOUN appos
#    SPACE dep
# plantílla NOUN obj
#   SPACE dep
# vigente ADJ amod
# desde ADP case
#   SPACE dep
# 27062017 NUM obl
#    SPACE dep
# iso NOUN compound
# 90012008 NUM compound
#   SPACE dep
# ntc INTJ appos
# gp PROPN obl
# 10002009 NUM nummod
#   SPACE dep
# bureau NOUN obj
#   SPACE dep
# yeritas NOUN obj
#    SPACE dep
# ceflific ADP appos
# ation NOUN fixed
#    SPACE dep
# rcolloizloi ADJ amod
# iofplloiiiu NOUN nmod
#   SPACE dep
# i CCONJ cc
#    SPACE dep
# defensoria ADJ conj
#   SPACE dep
# del ADP case
# pueblo NOUN nmod
#    SPACE dep
# colo NOUN appos
# mb PROPN appos
# ia PROPN obj
#      SPACE dep
# evidencia VERB advcl
# la DET det
# posibilidad NOUN obj
# de ADP case
# riesgo NOUN nmod
# de ADP case
# homicidios NOUN nmod
# selectivos ADJ amod
# cuyo PRON nmod
# fin NOUN nsubj
# podría AUX aux
# ser AUX cop
# el DET det
# control NOUN acl
#   SPACE dep
# poblacional ADJ amod
# a ADP case
# través NOUN fixed
#   SPACE dep
# de ADP fixed
# prácticas NOUN nmod
#   SPACE dep
# violencias NOUN nmod
#   SPACE dep
# ejemplarizantes ADJ nsubj
#      SPACE dep
# los DET det
# grupos NOUN nsubj
# armados ADJ amod
#   SPACE dep
# ilegales ADJ amod
# pretenden VERB advcl
# posicionarse VERB xcomp
#   SPACE dep
# de ADP case
# forma NOUN obl
#   SPACE dep
# violenta ADJ amod
# en ADP case
# el DET det
# territorio NOUN obl
#   SPACE dep
# para ADP mark
# lo PRON det
#   SPACE dep
# cual PRON nsubj
# doblegan VERB advcl
# a ADP case
# la DET det
# población NOUN obj
# civil ADJ amod
# que PRON nsubj
# queda VERB acl
# en ADP case
# medio NOUN fixed
# de ADP fixed
# la DET det
# acción NOUN obl
# armada ADJ amod
# convocan VERB advcl
# a ADP case
#   SPACE dep
# reuniones NOUN obj
#   SPACE dep
# a ADP case
# la DET det
# comunidad NOUN nmod
# y CCONJ cc
# declaran VERB conj
# abiertamente ADV advmod
# la DET det
# confrontación NOUN obj
# con ADP case
# otras DET det
# agrupaciones NOUN nmod
#    SPACE dep
# el DET det
# 02 NUM appos
# de ADP case
# diciembre NOUN compound
# de ADP case
# 2017 NUM compound
# el DET det
# grupo NOUN nsubj
# armado ADJ amod
# ilegal ADJ obj
# identificado ADJ amod
# como SCONJ mark
# autodefensas ADJ obj
# g NOUN nmod
#   SPACE dep
# t ADJ appos
# istas ADJ amod
#   SPACE dep
# de ADP case
# colombia PROPN nmod
# agc PROPN flat
#   SPACE dep
# realiza VERB advcl
#   SPACE dep
# una DET det
# reunión NOUN obj
# en ADP case
# el DET det
# centro NOUN nmod
# poblado ADJ amod
# del ADP case
# corregimiento NOUN nmod
#     SPACE dep
# sim NOUN appos
# en ADP case
#   SPACE dep
# el DET det
# municipio NOUN obl
# de ADP case
# cumbitara VERB advmod
# al ADP case
# parecer VERB fixed
# el DET det
# objetivo NOUN obj
# de ADP case
# la DET det
# reunión NOUN nmod
# era AUX cop
# comanicar1 VERB advcl
# e CCONJ cc
# a ADP case
# la DET det
#   SPACE dep
# ciudadanía NOUN conj
#   SPACE dep
# la DET det
# llegada NOUN obj
# de ADP case
# este DET det
# grupo NOUN nmod
# a ADP case
# la DET det
# zona NOUN nmod
#   SPACE dep
# así ADV cc
# como SCONJ fixed
#   SPACE dep
# la DET det
# retoma NOUN obl
# del ADP case
#   SPACE dep
# ter1íto NOUN nmod
# · PUNCT punct
# o CCONJ cc
# al ADP case
# daño NOUN conj
# en ADP case
#   SPACE dep
# el DET det
# que PRON obl
# combatirán VERB acl
# a ADP case
# otros DET det
# grupos NOUN obj
#   SPACE dep
# así ADV mark
# como SCONJ fixed
#   SPACE dep
# ir AUX aux
# estableciendo VERB advcl
# las DET det
# nuevas ADJ amod
# regtas NOUN obj
# que PRON nsubj
# regirán VERB acl
#   SPACE dep
# el DET det
# territorio NOUN obj
#      SPACE dep
# con ADP case
# el DET fixed
# objetivo NOUN obl
# de ADP mark
# fortalecerse VERB acl
# sus DET det
# estructuras NOUN obj
#   SPACE dep
# los DET det
# grupos NOUN nsubj
#   SPACE dep
# rm NOUN obj
# ...
# el DET det
# fin NOUN obl
#   SPACE dep
# de ADP mark
# ofrecer VERB acl
# garaatias NOUN obj
# pa NOUN case
# a ADP case
# el DET det
# acceso NOUN obl
# a ADP case
# la DET det
# verdad NOUN nmod
# justicia NOUN appos
# y CCONJ cc
# no ADV advmod
# repetición ADJ conj
# a ADP case
# la DET det
# población NOUN obj
#   SPACE dep
# víctima NOUN obj
# residente ADJ amod
# de ADP case
# la DET det
# zona NOUN nmod
# objeto NOUN amod
# de ADP case
# esta DET det
# alerta NOUN nmod
# temprana ADJ amod
#   SPACE dep
# de ADP case
# inminencia NOUN nmod
#      SPACE dep
# 11 NUM nummod
# a ADP case
# la DET det
# gobernación NOUN nmod
#   SPACE dep
# de ADP case
# nariño NOUN nmod
# para ADP mark
# que SCONJ mark
#   SPACE dep
# según ADP case
# lo PRON det
# establecido ADJ advcl
# en ADP case
# el DET det
# decreto NOUN obl
# 0341 NUM compound
# de ADP case
# agosto NOUN compound
#   SPACE dep
# de ADP case
# 2016 NOUN nmod
# por ADP case
# meaio NOUN advmod
# del ADP case
# cual PRON nmod
# se PRON expl:pass
# define VERB acl
# la DET det
# estrategia NOUN nsubj
# de ADP case
# corresponsabilidad NOUN nmod
# de ADP case
# la DET det
# política NOUN nmod
#   SPACE dep
# pública ADJ amod
# para ADP case
# as SYM fixed
# víctimas NOUN nmod
# del ADP case
# conflicto NOUN nmod
# armado ADJ amod
# interno ADJ amod
# contemplada ADJ amod
# en ADP case
# el DET det
# artícúlo NOUN obl
#   SPACE dep
# 2283125 NUM appos
# del ADP case
# decreto NOUN nmod
#   SPACE dep
# 2460 NUM compound
# de ADP case
# 2015 NOUN compound
# en ADP case
# el DET det
# departamento NOUN obl
#   SPACE dep
# de ADP case
# nariño NOUN nmod
#   SPACE dep
# socialice VERB csubj
#   SPACE dep
# habilite VERB xcomp
#   SPACE dep
# e CCONJ cc
# imple VERB conj
#   SPACE dep
# ente NOUN obj
# en ADP case
# la DET det
# zona NOUN obl
# objeto NOUN nmod
# de ADP case
# la DET det
# presente ADJ amod
# alerta NOUN nmod
# temprana ADJ amod
# de ADP case
# inminencia ADJ nmod
# las DET det
#   SPACE dep
# herramientas NOUN obj
#   SPACE dep
# que PRON obj
# esta DET det
# entidad NOUN nsubj
# territorial ADJ amod
# ha AUX aux
# dispuesto VERB acl
# en ADP case
# materia NOUN obl
# adecuación NOUN obj
#   SPACE dep
# institucional ADJ amod
# articulación NOUN obl
# asistencia ADJ nmod
# técnica ADJ amod
# e CCONJ cc
# implementación NOUN conj
# del ADP case
# modelo NOUN nmod
# departamental ADJ amod
#   SPACE dep
# de ADP case
# priorización NOUN nmod
#      SPACE dep
# 12 NUM nummod
# al ADP case
# ministerio NOUN nmod
# de ADP case
# salud PROPN nmod
# instituto PROPN appos
# departamental ADJ amod
# de ADP case
# salud NOUN nmod
# direcciones NOUN amod
# locales ADJ amod
# de ADP case
# salud NOUN nmod
# y CCONJ cc
#   SPACE dep
# hospitales NOUN conj
# o CCONJ cc
# centros NOUN conj
# de ADP case
# salud NOUN nmod
# de ADP case
# los DET det
# municipios NOUN nmod
# policarpa ADJ amod
# cumbitara AUX advcl
# magüí NOUN obj
# payán ADJ amod
# y CCONJ cc
#   SPACE dep
# roberto NOUN conj
# payán ADP case
# la DET det
# instalación NOUN obj
# de ADP case
# capacidades NOUN nmod
# humanas ADJ amod
# y CCONJ cc
# técnicas ADJ conj
# para ADP case
# la DET det
# implementación NOUN nmod
#   SPACE dep
# del ADP case
# programa NOUN nmod
#   SPACE dep
# de ADP case
# atención NOUN nmod
# psicosocial ADJ amod
# y CCONJ cc
# salud NOUN conj
# integral ADJ amod
# a ADP case
# víctimas NOUN nmod
#   SPACE dep
# del ADP case
# conflicto NOUN nmod
# armado ADJ amod
#         SPACE dep
# carrera NOUN appos
#   SPACE dep
# 9 NUM compound
#   SPACE dep
# 1621 NOUN nmod
# bogotá ADJ amod
# dc PROPN appos
#   SPACE dep
# pbx PROPN flat
# 57 NUM appos
# 1 NUM nummod
# 3147300 NUM compound
# línea NOUN appos
# nacional ADJ amod
# 01 NUM nummod
# 8000 NUM compound
# 914814 NUM nummod
#    SPACE dep
# wwwdefensoriagov NOUN nmod
# co ADJ amod
#   SPACE dep
# plantilla NOUN nmod
#   SPACE dep
# vigente ADJ amod
#   SPACE dep
# desde ADP case
#   SPACE dep
# 27062017 NUM obl
#    SPACE dep
# iso NOUN compound
# 90012008 NUM compound
#   SPACE dep
# ntc INTJ appos
# gp PROPN nmod
# 1000zoos NUM nmod
#     SPACE dep
# bureau NOUN nmod
#   SPACE dep
# veritas NOUN nmod
#     SPACE dep
# certification ADJ amod
#     SPACE dep
# lc81uiz30l VERB amod
# in ADP case
# ip110mlls NOUN nmod
#       SPACE dep
# defensoria ADJ amod
#   SPACE dep
# del ADP case
# pueblo NOUN nmod
#     SPACE dep
# colomiia VERB conj
#     SPACE dep
# papsivi ADJ amod
# el DET det
# cual PRON nsubj
# deberá AUX aux
# ser AUX aux
# acompañado VERB csubj
# de ADP case
# jornadas NOUN obj
#   SPACE dep
# de ADP case
# socialización NOUN nmod
# de ADP case
# rutas NOUN nmod
# de ADP case
# atención NOUN nmod
#   SPACE dep
# dirigidas ADJ amod
# a ADP case
# autoridades NOUN obj
# civiles ADJ amod
# y CCONJ cc
# tradicionales ADJ conj
# con ADP case
# especial ADJ amod
# prioridad NOUN obl
# en ADP case
# funcionarios NOUN nmod
# de ADP case
#   SPACE dep
# personerías NOUN nmod
# y CCONJ cc
# administraciones NOUN conj
# municipales ADJ amod
# especialmente ADV advmod
# secretarías ADJ amod
# de ADP case
# despacho NOUN nmod
#   SPACE dep
# enlaces NOUN appos
# municipales ADJ amod
# de ADP case
# víctimas NOUN nmod
# inspecciones ADJ amod
# de ADP case
# policía NOUN nmod
# y CCONJ cc
# comisarías NOUN conj
# de ADP case
# familia NOUN nmod
#      SPACE dep
# 13 NUM nummod
# a ADP case
# la DET det
# comisión NOUN nmod
# lntersectorial ADJ amod
#   SPACE dep
# para ADP case
# la DET det
# prevención NOUN nmod
# del ADP case
#   SPACE dep
# reclutamiento NOUN nmod
# y CCONJ cc
# la DET det
# utilización NOUN conj
# de ADP case
# niños NOUN nmod
#   SPACE dep
# niñas NOUN flat
#   SPACE dep
# adolescentes NOUN appos
# y CCONJ cc
# jóvenes NOUN conj
#   SPACE dep
# por ADP case
# grupos NOUN nmod
#   SPACE dep
# armados ADJ amod
#   SPACE dep
# ilegales ADJ amod
#   SPACE dep
# para ADP mark
# que SCONJ mark
# con ADP case
# el DET det
# co1kllfs NOUN obl
# de ADP case
# las DET det
#   SPACE dep
# instancias NOUN nmod
# que PRON nsubj
# conforman VERB acl
# el DET det
# sistema NOUN obj
# nacional ADJ amod
# de ADP case
# bienestar NOUN nmod
#   SPACE dep
# familiar ADJ amod
# o CCONJ cc
# dinen VERB conj
# las DET det
#   SPACE dep
# acciones NOUN obj
# necesarias ADJ amod
# en ADP case
#   SPACE dep
# términos NOUN nmod
# de ADP case
# políticas NOUN nmod
# y CCONJ cc
# estrategias NOUN conj
# para ADP mark
# prevenir VERB advcl
# el DET det
# r NOUN obj
# eclutaniento ADJ nmod
#   SPACE dep
# forzado ADJ amod
# de ADP case
# niños NOUN nmod
# niñas NOUN flat
# adolescentes ADJ amod
# y CCONJ cc
# jóvenes NOUN conj
# por ADP case
# parte NOUN fixed
# de ADP fixed
# actores NOUN nmod
# ar ADJ amod
#   SPACE dep
# atlas NOUN nmod
#   SPACE dep
# · NOUN punct
# legales ADJ amod
# en ADP case
#   SPACE dep
# las DET det
# zonas NOUN obl
# rurales ADJ amod
#   SPACE dep
# de ADP case
# los DET det
# municipios NOUN nmod
# de ADP case
# policarpa NOUN nmod
# cumbitara VERB advmod
#   SPACE dep
# magüí NOUN obj
#   SPACE dep
# payáfl NOUN obj
#   SPACE dep
# y CCONJ cc
# · NOUN conj
# alerto VERB obj
# payán ADP case
#      SPACE dep
# 14 NUM obl
# a ADP case
# la DET det
# unidad NOUN obj
# para ADP case
# las DET det
# víctimas NOUN obl
# en ADP case
# articulación NOUN nmod
# con ADP case
# las DET det
# alcaldías NOUN nmod
#   SPACE dep
# tj PROPN appos
# icf PROPN advmod
# ates NOUN obj
# y CCONJ cc
# personerías NOUN conj
#   SPACE dep
# municipales ADJ amod
#   SPACE dep
# de ADP case
# policarpa NOUN nmod
#   SPACE dep
# cumbitara VERB advmod
#   SPACE dep
# magüí ADJ amod
#   SPACE dep
# payán ADJ amod
# y CCONJ cc
# roberto PROPN conj
# ra PROPN flat
# an PROPN flat
# rocuraduría PROPN flat
# regional ADJ amod
#   SPACE dep
# de ADP case
# nariño NOUN nmod
# y CCONJ cc
# la DET det
# procuraduría NOUN conj
# provincial ADJ amod
# de ADP case
# tumaco NOUN nmod
# la DET det
# r NOUN dep
#   SPACE dep
# h2ac1ón NOUN dep
# de ADP case
# capacitaciones NOUN nmod
# y CCONJ cc
#   SPACE dep
# talleres NOUN conj
#   SPACE dep
# dirigidos ADJ amod
# a ADP case
# personerías NOUN obj
#   SPACE dep
# municipales ADJ amod
#   SPACE dep
# y CCONJ cc
# enlaces NOUN conj
#   SPACE dep
# de ADP case
# vcti PROPN nmod
# as PROPN obj
# para ADP mark
# instalar VERB advcl
#   SPACE dep
# capacidades NOUN obj
#   SPACE dep
# para ADP case
# el DET det
# conocimiento NOUN nmod
# y CCONJ cc
# aplicación NOUN conj
# de ADP case
# la DET det
# ruta NOUN nmod
# de ADP case
# a ADP case
# enctó VERB nmod
# n NOUN nsubj
# a ADP case
# población NOUN nmod
# víctima NOUN appos
# de ADP case
#   SPACE dep
# desplazamiento NOUN nmod
# forzado ADJ amod
# haciendo VERB advcl
# especial ADJ amod
# énfasis NOUN obj
# en ADP case
# e CCONJ cc
#   SPACE dep
# procedimiento NOUN obj
# para ADP case
# toma NOUN nmod
# de ADP case
#   SPACE dep
# declaraciones NOUN nmod
# y CCONJ cc
# definiendo VERB conj
# una DET det
# ruta NOUN obj
# de ADP case
# apoy VERB acl
#   SPACE dep
# t NOUN obj
# c NOUN amod
# ico ADJ amod
# en ADP case
# terreno NOUN obl
# cuando SCONJ mark
# estos DET det
# hechos NOUN nsubj
#   SPACE dep
# sobrepasen VERB advcl
# la DET det
# capacidad NOUN obj
# institucional ADJ amod
# municip PROPN appos
#   SPACE dep
# l PROPN flat
#     SPACE dep
# 15 NUM appos
# a ADP case
# la DET det
# unidad NOUN nmod
# para ADP case
# las DET det
# víctimas NOUN nmod
#   SPACE dep
# en ADP mark
# coordinaqióh NOUN advcl
# con ADP case
# a ADP fixed
# gobernación NOUN compound
# de ADP case
#   SPACE dep
# nariño NOUN obj
# y CCONJ cc
# las DET det
# alcaldías NOUN conj
#   SPACE dep
# de ADP case
# policarpa NOUN nmod
#   SPACE dep
# cumbitara VERB advcl
#   SPACE dep
# magüí ADJ amod
#   SPACE dep
# payán ADJ amod
# f NOUN obj
#   SPACE dep
# t NOUN obj
# rt0 ADJ flat
# payán ADJ obj
# para ADP case
# la DET det
# realización NOUN nmod
# de ADP case
# jornadas NOUN nmod
#   SPACE dep
# de ADP case
#   SPACE dep
# capacitación NOUN nmod
# sobre ADP case
# la DET det
# rutas NOUN nmod
# de ADP case
# ate PROPN nmod
# ión PROPN flat
# p NOUN flat
#   SPACE dep
# ra DET punct
# víctimas NOUN obj
# de ADP case
# desaparición NOUN nmod
# forzada ADJ amod
# la DET det
# cual PRON nsubj
#   SPACE dep
# deberá AUX aux
# dirigirse VERB acl
# a ADP case
# autoridades NOUN obj
# civiles ADJ amod
#   SPACE dep
# hitares ADJ amod
# y CCONJ cc
# tradicionales ADJ conj
#   SPACE dep
# con ADP case
# especial ADJ amod
# prioridad NOUN obl
# en ADP case
#   SPACE dep
# funcionarios NOUN nmod
# de ADP case
# las DET det
# personef PROPN nmod
# ia PROPN amod
# manicipal ADJ amod
# y CCONJ cc
# de ADP case
# las DET det
# administraciones NOUN conj
# municipales ADJ amod
#   SPACE dep
# concernidas ADJ amod
# especialmente ADV advmod
# secretarías ADJ obj
# de ADP case
# despacho NOUN obl
# enlace NOUN flat
# municipal ADJ amod
# de ADP case
# víctimas NOUN nmod
#    SPACE dep
# lnspecció VERB advcl
# de ADP case
#   SPACE dep
# policía NOUN obj
# y CCONJ cc
# cormisaría NOUN conj
#   SPACE dep
# e CCONJ cc
# familia NOUN conj
#      SPACE dep
# 16 NUM nummod
# a ADP case
# las DET det
# personerías NOUN obj
# munfo ADJ amod
# ipales ADJ amod
# de ADP case
# policarpa NOUN nmod
#   SPACE dep
# cumbitara VERB xcomp
# magüí NOUN obj
# payán ADJ amod
# y CCONJ cc
# roberto NOUN conj
# payán ADP mark
#   SPACE dep
# efectuar VERB xcomp
#   SPACE dep
# seguimiento NOUN obj
# y CCONJ cc
# yigilancia NOUN conj
# a ADP case
# las DET det
# acciones NOUN obl
# de ADP case
#   SPACE dep
# los DET det
# organismos NOUN nmod
# competentes ADJ amod
#   SPACE dep
# del ADP case
# orden NOUN nmod
#   SPACE dep
# local ADJ amod
# de ADP case
# acuerdo NOUN fixed
# con ADP case
# lo PRON det
# reseñado ADJ amod
# en ADP case
# el DET det
# presente ADJ amod
# alerta NOUN obl
# temprana ADJ amod
# de ADP case
# inminencia NOUN nmod
#      SPACE dep
# 17 NUM nummod
# a ADP case
# la DET det
# procuraduría NOUN nmod
# regional ADJ amod
# de ADP case
# nariño NOUN nmod
# y CCONJ cc
# la DET det
# procuraduría NOUN conj
# provincial ADJ amod
# de ADP case
# tumaco NOUN nmod
# efectuar VERB xcomp
#   SPACE dep
# seguimie PROPN obj
# rto PROPN obj
# y CCONJ cc
# vjgilancia NOUN conj
#   SPACE dep
# a ADP case
# las DET det
# acciones NOUN nmod
# de ADP case
#   SPACE dep
# los DET det
# organismos NOUN nmod
# competentes ADJ amod
# del ADP case
# orden NOUN nmod
# local ADJ amod
# · PROPN punct
# de ADP case
#   SPACE dep
# ac PROPN dep
# erao PROPN flat
# eon PROPN dep
# lo PRON obj
# reseñado ADJ obj
# en ADP case
# el DET det
#   SPACE dep
# presente ADJ amod
# informe NOUN obl
# de ADP case
# riesgo NOUN nmod
# de ADP case
# inminencia ADJ nmod
#                SPACE dep
# carrera NOUN nmod
#   SPACE dep
# 9 NUM nummod
#   SPACE dep
# 1621 NOUN obl
# bogotá ADJ amod
# dc PROPN appos
#   SPACE dep
# pbx PROPN flat
# 57 NUM appos
# 1 NUM nummod
# 3147300 NUM appos
# línea VERB appos
# nacional ADJ amod
#   SPACE dep
# 018000914814 NUM appos
#    SPACE dep
# wwwdefensoriagovco NOUN appos
#    SPACE dep
# plantilla NOUN appos
# vigente ADJ amod
# des NOUN appos
# de ADP case
# 2706 NUM nmod
# 2017 NUM appos
#    SPACE dep
# iso NOUN appos
# 90012008 NUM nummod
#   SPACE dep
# ntc INTJ obj
# gp PROPN flat
# 1000 NUM appos
# 2009 NUM obl
#    SPACE dep
# bureau NOUN compound
#   SPACE dep
# veritas NOUN obj
#    SPACE dep
# certificlti PROPN flat
# oa PROPN advmod
#    SPACE dep
# i CCONJ cc
# coii PROPN conj
# ollqs ADJ amod
# fl PROPN nmod
# spiigmlll PROPN flat
#     SPACE dep
# defensoria ADJ amod
#   SPACE dep
# del ADP case
# pueblo NOUN nmod
#     SPACE dep
# col0m61a NOUN obl
#     SPACE dep
# a ADP case
# la DET det
# ciprat NOUN obl
#   SPACE dep
# informar VERB xcomp
#   SPACE dep
# a ADP case
# la DET det
# dirección NOUN obj
# del ADP case
# sistema NOUN nmod
#   SPACE dep
# de ADP case
# alertas NOUN nmod
#   SPACE dep
# tempranas ADJ amod
#   SPACE dep
# sat PROPN appos
#   SPACE dep
# de ADP case
# la DET det
# defensoría NOUN nmod
#   SPACE dep
# del ADP case
# pueblo NOUN nmod
# las DET det
#   SPACE dep
# actuaciones NOUN obj
# y CCONJ cc
# medidas NOUN conj
# adoptadas ADJ amod
# con ADP case
# respecto NOUN fixed
# a ADP fixed
# las DET det
# recomendaciones NOUN obl
#   SPACE dep
# formuladas ADJ amod
# en ADP case
# la DET det
# presente ADJ amod
# advertencia NOUN obl
# conforme NOUN case
# a ADP fixed
# lo PRON det
# previsto ADJ amod
# en ADP case
# la DET det
# corte NOUN obl
# constitucional ADJ amod
#   SPACE dep
# y CCONJ cc
# la DET det
#   SPACE dep
# ley NOUN conj
# 24 NUM nummod
# de ADP case
# 1992 NOUN compound
# dicha ADJ amod
# información NOUN nsubj
# deberá AUX aux
# ser AUX aux
# allegada VERB advcl
# dentro ADV advmod
# de ADP case
# los DET det
#   SPACE dep
# cinco NUM nummod
#   SPACE dep
# días NOUN obl
# siguientes ADJ amod
# al ADP case
#   SPACE dep
# recibo NOUN nmod
# del ADP case
# presente NOUN nmod
# según ADP case
# lo PRON det
#   SPACE dep
# estipulado VERB advcl
# en ADP case
# el DET det
# artículo NOUN obl
# 15 NUM appos
# y CCONJ cc
# subsiguientes ADJ conj
#   SPACE dep
# de ADP case
# la DET det
# ley PROPN nmod
# 24 NUM nummod
#   SPACE dep
# del ADP case
# 15 NUM nummod
#   SPACE dep
# de ADP case
# diciembre NOUN compound
# de ADP case
# 1992 NUM compound
# a ADP case
# los DET det
# siguientes ADJ amod
# datos NOUN obj
# de ADP case
# contacto NOUN nmod
#      SPACE dep
# • ADJ flat
# correo NOUN appos
# electrónico ADJ amod
# institucional ADJ amod
# jeguzmandefensoriagovco ADJ amod
#   SPACE dep
# y CCONJ cc
#   SPACE dep
# fegaitan VERB conj
# defensoria PROPN obj
# govco ADJ amod
#   SPACE dep
# • ADJ dep
# dirección NOUN obj
# postal ADJ amod
# carrera NOUN nmod
# 9 NUM nummod
# nº NOUN nmod
#   SPACE dep
# pueblo NOUN appos
#      SPACE dep
# cordialmente ADV advmod
#   SPACE dep
# tá INTJ dep
# dc DET flat
# código PROPN flat
# postal ADJ amod
#   SPACE dep
# 1103 NUM obl
# fert ADJ obj
# soría VERB conj
#   SPACE dep
# del ADP case
#   SPACE dep
# 1 NUM obl
# · NOUN punct
#     SPACE dep
# rafael PROPN obj
#   SPACE dep
# h NOUN flat
# ando VERB advcl
#   SPACE dep
# navarr PROPN obj
#   SPACE dep
# o CCONJ cc
#    SPACE dep
# profesional NOUN conj
#   SPACE dep
# especi VERB flat
#   SPACE dep
# defensor NOUN obj
#   SPACE dep
# delegad VERB advcl
#    SPACE dep
# violaciones NOUN obj
#   SPACE dep
# zado ADJ amod
# con ADP case
# fun NOUN obl
# io DET det
#    SPACE dep
# das VERB obj
# de ADP case
#   SPACE dep
# ara VERB flat
# la DET det
# pr PROPN appos
#    SPACE dep
# e CCONJ cc
# riesgos NOUN conj
# de ADP case
#   SPACE dep
# os PRON nmod
# derech NOUN obj
#   SPACE dep
# · PUNCT punct
# os PRON obj
# y CCONJ cc
# dih NOUN conj
#          SPACE dep
# pro NOUN compound
# e CCONJ cc
# tó NUM conj
# garobayo1 NOUN obj
#     SPACE dep
# revi VERB amod
# so VERB advmod
# rnavarro NOUN fixed
#   SPACE dep
# · NOUN punct
#     SPACE dep
# archivado ADJ amod
# en ADP case
# a ADP fixed
# as NOUN fixed
#   SPACE dep
# tempranas ADJ amod
#   SPACE dep
# 2018 NOUN obl
#   SPACE dep
# consecutivo ADJ amod
# dependencia NOUN appos
# 404001 NUM appos
# 0004 NUM appos
# l ADJ appos
# 8 NUM nummod
#                                            SPACE dep
# carrera NOUN nmod
#   SPACE dep
# 9 NUM nummod
#   SPACE dep
# 1621 NOUN obj
# bogotá ADJ amod
# dc PROPN appos
#   SPACE dep
# pbx PROPN flat
#   SPACE dep
# 57 NUM nummod
# 1 NUM appos
# 3147300 NUM obl
# línea VERB obj
# nacional ADJ amod
#   SPACE dep
# 01 NUM appos
# 8000 NUM nmod
# 914814 NUM appos
#    SPACE dep
# wwwdefensoriagovco NOUN obj
#    SPACE dep
# plantilla NOUN obj
#   SPACE dep
# vigente ADJ amod
#   SPACE dep
# desde ADP case
#   SPACE dep
# 27062017 NUM obl
#    SPACE dep
# iso NOUN compound
# 90012008 NUM compound
#   SPACE dep
# ntc INTJ obj
# gp PROPN flat
# 1000 NUM nummod
# 2009 NUM obl
#    SPACE dep
# bureau NOUN obj
#   SPACE dep
# veritas NOUN obj
#    SPACE dep
# certification NOUN conj
#     SPACE dep
# rai1101l0l1rs11m111s ADJ amod
# o CCONJ punct
#    SPACE dep
# []

# %% [markdown]
# # 7. Export HTML

# %%
# !jupyter nbconvert --to html 5_Actores_del_Conflicto.ipynb
# Out:
# [NbConvertApp] Converting notebook 4_Distribution_of_documents_Departamentos.ipynb to html
# [NbConvertApp] Writing 1281710 bytes to 4_Distribution_of_documents_Departamentos.html
